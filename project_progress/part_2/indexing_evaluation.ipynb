# %% [markdown]
# # Part 1: Indexing

# %% [markdown]
# #### Imports

# %%
import nltk
import json
from collections import defaultdict
from array import array
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
import math
import numpy as np
import collections
from numpy import linalg as la
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# from wordcloud import WordCloud
from collections import Counter

# %% [markdown]
# #### Useful code from part 1

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def remove_punctuation(text):
    cleaned = ""
    for char in text:
        if char.isalnum() or char.isspace() or char == "-":
            cleaned += char
        else:
            cleaned += " "  # Replace punctuation with space
    return cleaned

# %%
products_path = '../../data/fashion_products_dataset.json'
with open(products_path, "r", encoding="utf-8") as f:
    products = pd.read_json(products_path)

def build_terms(line):
    """
    Preprocess a line:
    ●  Removing stop words 
    ●  Tokenization 
    ●  Removing punctuation marks 
    ●  Stemming 
    ●  Transforming to lowercase

    Argument:
    line -- string (text) to be preprocessed

    Returns:
    line - a list of tokens corresponding to the input text after the preprocessing
    """

    stemmer = PorterStemmer()
    stop_words = set(stopwords.words("english"))
    line = line.lower()
    line = remove_punctuation(line)
    line = line.split()
    line = [x for x in line if x not in stop_words]
    line = [stemmer.stem(word) for word in line]
    return line

def get_products_information(products_df):
    elements = ["pid", "title", "description", "brand", "category", "sub_category", 
                "product_details", "seller", "out_of_stock", "selling_price", 
                "discount", "actual_price", "average_rating", "url"]
    
    products_df = products_df[elements]
    
    return products_df

products = get_products_information(products)
products["processed_title"] = products["title"].apply(build_terms)
products["processed_description"] = products["description"].apply(build_terms)
products['cat_subcat'] = products['category'] + ": " + products['sub_category']

# %% [markdown]
# # Part 1: Indexing

# %% [markdown]
# ## 1. Build inverted index

# %% [markdown]
# We join the words in the processed titles and the processed descriptions for each product

# %%
products["title_description"] = products["processed_title"] + products["processed_description"]
display(products.head(5))
# Out:
#                 pid                                title  \
# 0  TKPFCZ9EA7H5FYZH   Solid Women Multicolor Track Pants
# 1  TKPFCZ9EJZV2UVRZ           Solid Men Blue Track Pants
# 2  TKPFCZ9EHFCY5Z4Y     Solid Men Multicolor Track Pants
# 3  TKPFCZ9ESZZ7YWEF   Solid Women Multicolor Track Pants
# 4  TKPFCZ9EVXKBSUD7  Solid Women Brown, Grey Track Pants
#
#                                          description brand  \
# 0  Yorker trackpants made from 100% rich combed c...  York
# 1  Yorker trackpants made from 100% rich combed c...  York
# 2  Yorker trackpants made from 100% rich combed c...  York
# 3  Yorker trackpants made from 100% rich combed c...  York
# 4  Yorker trackpants made from 100% rich combed c...  York
#
#                    category sub_category  \
# 0  Clothing and Accessories   Bottomwear
# 1  Clothing and Accessories   Bottomwear
# 2  Clothing and Accessories   Bottomwear
# 3  Clothing and Accessories   Bottomwear
# 4  Clothing and Accessories   Bottomwear
#
#                                      product_details             seller  \
# 0  [{'Style Code': '1005COMBO2'}, {'Closure': 'El...  Shyam Enterprises
# 1  [{'Style Code': '1005BLUE'}, {'Closure': 'Draw...  Shyam Enterprises
# 2  [{'Style Code': '1005COMBO4'}, {'Closure': 'El...  Shyam Enterprises
# 3  [{'Style Code': '1005COMBO3'}, {'Closure': 'El...  Shyam Enterprises
# 4  [{'Style Code': '1005COMBO1'}, {'Closure': 'Dr...  Shyam Enterprises
#
#    out_of_stock selling_price discount actual_price average_rating  \
# 0         False           921  69% off        2,999            3.9
# 1         False           499  66% off        1,499            3.9
# 2         False           931  68% off        2,999            3.9
# 3         False           911  69% off        2,999            3.9
# 4         False           943  68% off        2,999            3.9
#
#                                                  url  \
# 0  https://www.flipkart.com/yorker-solid-men-mult...
# 1  https://www.flipkart.com/yorker-solid-men-blue...
# 2  https://www.flipkart.com/yorker-solid-men-mult...
# 3  https://www.flipkart.com/yorker-solid-men-mult...
# 4  https://www.flipkart.com/yorker-solid-men-brow...
#
#                             processed_title  \
# 0   [solid, women, multicolor, track, pant]
# 1           [solid, men, blue, track, pant]
# 2     [solid, men, multicolor, track, pant]
# 3   [solid, women, multicolor, track, pant]
# 4  [solid, women, brown, grey, track, pant]
#
#                                processed_description  \
# 0  [yorker, trackpant, made, 100, rich, comb, cot...
# 1  [yorker, trackpant, made, 100, rich, comb, cot...
# 2  [yorker, trackpant, made, 100, rich, comb, cot...
# 3  [yorker, trackpant, made, 100, rich, comb, cot...
# 4  [yorker, trackpant, made, 100, rich, comb, cot...
#
#                              cat_subcat  \
# 0  Clothing and Accessories: Bottomwear
# 1  Clothing and Accessories: Bottomwear
# 2  Clothing and Accessories: Bottomwear
# 3  Clothing and Accessories: Bottomwear
# 4  Clothing and Accessories: Bottomwear
#
#                                    title_description
# 0  [solid, women, multicolor, track, pant, yorker...
# 1  [solid, men, blue, track, pant, yorker, trackp...
# 2  [solid, men, multicolor, track, pant, yorker, ...
# 3  [solid, women, multicolor, track, pant, yorker...
# 4  [solid, women, brown, grey, track, pant, yorke...

# %%
def create_index_tfidf_products(products):
    index = defaultdict(list)
    tf = defaultdict(list)
    df = defaultdict(int)
    idf = defaultdict(float)
    title_index = defaultdict(str)

    num_documents = len(products)

    for i in range(num_documents):
        pid = products.iloc[i]["pid"]
        words = products.iloc[i]["title_description"]
        title_index[pid] = products.iloc[i].get("title", "")

        current_product_index = {}

        for position, term in enumerate(words):
            try:
                current_product_index[term][1].append(position)
            except:
                current_product_index[term] = [pid, array('I', [position])]

        norm = math.sqrt(sum(len(posting[1]) ** 2 for posting in current_product_index.values()))

        for term, posting in current_product_index.items():
            tf[term].append(np.round(len(posting[1]) / norm, 4))
            df[term] += 1

        for term, posting in current_product_index.items():
            index[term].append(posting)

    for term in df:
        idf[term] = np.round(np.log(float(num_documents / df[term])), 4)

    return index, tf, df, idf, title_index

# %% [markdown]
# ## 2. Propose test queries

# %%
queries = [
    "casual half sleeve polo shirt for men",
    "light blue jeans slim fit",
    "trousers chino casual men",
    "black sports shoes",
    "fancy t-shirt"
]

# %% [markdown]
# ## 3. Rank your results

# %%
def rank_documents(terms, prods, index, idf, tf, title_index):
    product_vectors = defaultdict(lambda: [0] * len(terms))
    query_vector = [0] * len(terms)

    query_terms_count = collections.Counter(terms)
    query_norm = la.norm(list(query_terms_count.values()))

    for term_index, term in enumerate(terms):
        if term not in index:
            continue

        query_vector[term_index] = query_terms_count[term] / query_norm * idf[term]

        for posting_index, (pid, positions) in enumerate(index[term]):
            if pid in prods:
                product_vectors[pid][term_index] = tf[term][posting_index] * idf[term]

    product_scores = [[np.dot(vec, query_vector), pid] for pid, vec in product_vectors.items()]
    product_scores.sort(reverse=True)
    ranked_prods = [pid for _, pid in product_scores]

    return ranked_prods, product_scores

def search_tf_idf(query, index, idf, tf, title_index):
    query = build_terms(query)
    prods = None

    for term in query:
        try:
            term_prods = set(posting[0] for posting in index[term])
            if prods is None:
                prods = term_prods
            else:
                prods &= term_prods
        except:
            return [], []

    if not prods:
        return [], []

    prods = list(prods)
    ranked_prods, prod_scores = rank_documents(query, prods, index, idf, tf, title_index)
    return ranked_prods, prod_scores

# %%
index, tf, df, idf, title_index = create_index_tfidf_products(products)

# %%
queries = [
    "casual half sleeve polo shirt for men",
    "light blue jeans slim fit",
    "trousers chino casual men",
    "black sports shoes",
    "fancy t-shirt"
]

for query in queries:
    print(f"\nQuery: {query}")
    ranked_prods, scores = search_tf_idf(query, index, idf, tf, title_index)
    top = min(10, len(ranked_prods))

    print("\n======================\nTop {} results out of {} for the searched query:\n".format(top, len(ranked_prods)))
    for score, pid in scores[:top]:
        url = products.loc[products["pid"] == pid, "url"].values
        url = url[0] if len(url) > 0 else "N/A"
        print("product_id = {} - product_title: {} - score: {:.4f} - url: {}".format(pid, title_index[pid], score, url))
# Out:
# Query: casual half sleeve polo shirt for men
#
# ======================
# Top 10 results out of 43 for the searched query:
#
# product_id = TSHEG64SDHDEZAGH - product_title: Solid Men Polo Neck Blue T-Shirt - score: 2.1961 - url: https://www.flipkart.com/teemoods-solid-men-polo-neck-blue-t-shirt/p/itmf3ysfnqxuen9r?pid=TSHEG64SDHDEZAGH&lid=LSTTSHEG64SDHDEZAGHDFBM4L&marketplace=FLIPKART&srno=b_1_22&otracker=browse&fm=organic&iid=4448bc13-3c41-4a59-8584-a811c8e4784f.TSHEG64SDHDEZAGH.SEARCH&ssid=5yyou4hsu80000001612412157763
# product_id = TSHEG5Y3ZNYCADMV - product_title: Solid Men Polo Neck White T-Shirt - score: 2.1961 - url: https://www.flipkart.com/teemoods-solid-men-polo-neck-white-t-shirt/p/itmf3ytvdrcjqbb2?pid=TSHEG5Y3ZNYCADMV&lid=LSTTSHEG5Y3ZNYCADMVIW3S0U&marketplace=FLIPKART&srno=b_1_26&otracker=browse&fm=organic&iid=4448bc13-3c41-4a59-8584-a811c8e4784f.TSHEG5Y3ZNYCADMV.SEARCH&ssid=5yyou4hsu80000001612412157763
# product_id = TSHEG5FPJMEZQXBD - product_title: Solid Men Polo Neck Black T-Shirt - score: 2.1961 - url: https://www.flipkart.com/teemoods-solid-men-polo-neck-black-t-shirt/p/itmf3yturcwgjuwp?pid=TSHEG5FPJMEZQXBD&lid=LSTTSHEG5FPJMEZQXBDNG7JNB&marketplace=FLIPKART&srno=b_1_25&otracker=browse&fm=organic&iid=4448bc13-3c41-4a59-8584-a811c8e4784f.TSHEG5FPJMEZQXBD.SEARCH&ssid=5yyou4hsu80000001612412157763
# product_id = TSHFPD3VM8GGGEEX - product_title: Self Design Men Polo Neck Blue T-Shirt - score: 1.9046 - url: https://www.flipkart.com/byford-pantaloons-self-design-men-polo-neck-blue-t-shirt/p/itm00c40165636a1?pid=TSHFPD3VM8GGGEEX&lid=LSTTSHFPD3VM8GGGEEXWLYRVX&marketplace=FLIPKART&srno=b_1_37&otracker=browse&fm=organic&iid=98c379bb-2091-4c37-a3ae-a74ebab57fe9.TSHFPD3VM8GGGEEX.SEARCH&ssid=suuc275k0g0000001612099860265
# product_id = TSHFZP6HBDFGFWFC - product_title: Printed Men Polo Neck Blue T-Shirt - score: 1.8299 - url: https://www.flipkart.com/byford-pantaloons-printed-men-polo-neck-blue-t-shirt/p/itmbad0150d3f364?pid=TSHFZP6HBDFGFWFC&lid=LSTTSHFZP6HBDFGFWFC7OX4HA&marketplace=FLIPKART&srno=b_1_18&otracker=browse&fm=organic&iid=98c379bb-2091-4c37-a3ae-a74ebab57fe9.TSHFZP6HBDFGFWFC.SEARCH&ssid=suuc275k0g0000001612099860265
# product_id = TSHFPKNCQAQFNVKB - product_title: Striped Men Polo Neck Blue T-Shirt - score: 1.8299 - url: https://www.flipkart.com/byford-pantaloons-striped-men-polo-neck-blue-t-shirt/p/itmd111ac5d746b7?pid=TSHFPKNCQAQFNVKB&lid=LSTTSHFPKNCQAQFNVKB1UOWIR&marketplace=FLIPKART&srno=b_4_148&otracker=browse&fm=organic&iid=d9837832-a5e8-434a-b7d6-aad729fbc3c8.TSHFPKNCQAQFNVKB.SEARCH&ssid=3hq6midsj40000001612099862841
# product_id = TSHFPKNCFYGMWDDH - product_title: Striped Men Polo Neck Brown T-Shirt - score: 1.8299 - url: https://www.flipkart.com/byford-pantaloons-striped-men-polo-neck-brown-t-shirt/p/itmc8e0f3acba347?pid=TSHFPKNCFYGMWDDH&lid=LSTTSHFPKNCFYGMWDDHTVLOUQ&marketplace=FLIPKART&srno=b_3_102&otracker=browse&fm=organic&iid=a673353f-c642-4d35-a485-76d8dc44c5d0.TSHFPKNCFYGMWDDH.SEARCH&ssid=l66c4nft5c0000001612099861905
# product_id = TSHFPKNC3JEGVQCZ - product_title: Striped Men Polo Neck Blue T-Shirt - score: 1.8299 - url: https://www.flipkart.com/byford-pantaloons-striped-men-polo-neck-blue-t-shirt/p/itme0d75dda8173e?pid=TSHFPKNC3JEGVQCZ&lid=LSTTSHFPKNC3JEGVQCZQOESOY&marketplace=FLIPKART&srno=b_2_53&otracker=browse&fm=organic&iid=2a0752dd-cb39-48cd-94cf-13d82d34247f.TSHFPKNC3JEGVQCZ.SEARCH&ssid=ep3s3h17dc0000001612099861023
# product_id = TSHFKZYFJ8DXYPJG - product_title: Striped Men Polo Neck Beige T-Shirt - score: 1.8299 - url: https://www.flipkart.com/byford-pantaloons-striped-men-polo-neck-beige-t-shirt/p/itm6d07c5cae0e29?pid=TSHFKZYFJ8DXYPJG&lid=LSTTSHFKZYFJ8DXYPJGNSQFZM&marketplace=FLIPKART&srno=b_2_58&otracker=browse&fm=organic&iid=2a0752dd-cb39-48cd-94cf-13d82d34247f.TSHFKZYFJ8DXYPJG.SEARCH&ssid=ep3s3h17dc0000001612099861023
# product_id = TSHFK68SC4GBWKHN - product_title: Striped Men Polo Neck Yellow T-Shirt - score: 1.8299 - url: https://www.flipkart.com/byford-pantaloons-striped-men-polo-neck-yellow-t-shirt/p/itmdca12e98f9fbe?pid=TSHFK68SC4GBWKHN&lid=LSTTSHFK68SC4GBWKHNPG4OVA&marketplace=FLIPKART&srno=b_2_54&otracker=browse&fm=organic&iid=2a0752dd-cb39-48cd-94cf-13d82d34247f.TSHFK68SC4GBWKHN.SEARCH&ssid=ep3s3h17dc0000001612099861023
#
# Query: light blue jeans slim fit
#
# ======================
# Top 10 results out of 22 for the searched query:
#
# product_id = JEAFUZXSHCZNHQE4 - product_title: Tapered Fit Men Light Blue Jeans - score: 3.9304 - url: https://www.flipkart.com/ecko-unltd-tapered-fit-men-light-blue-jeans/p/itmc6aa2904b5b52?pid=JEAFUZXSHCZNHQE4&lid=LSTJEAFUZXSHCZNHQE4YPXRGC&marketplace=FLIPKART&srno=b_10_393&otracker=browse&fm=organic&iid=6b22e250-3c89-4099-a3ac-4e29e66e3727.JEAFUZXSHCZNHQE4.SEARCH&ssid=ebz05yghhs0000001612104158270
# product_id = JEAFUZXT2J3VV2RR - product_title: Tapered Fit Men Light Blue Jeans - score: 3.8475 - url: https://www.flipkart.com/ecko-unltd-tapered-fit-men-light-blue-jeans/p/itm09f8912e46d9e?pid=JEAFUZXT2J3VV2RR&lid=LSTJEAFUZXT2J3VV2RRNCHDC5&marketplace=FLIPKART&srno=b_15_594&otracker=browse&fm=organic&iid=01bc0c9e-8b44-41d4-9ab2-7682a12dcb6c.JEAFUZXT2J3VV2RR.SEARCH&ssid=wbc027vlq80000001612104162661
# product_id = JEAFSKYHHDQ2SDZQ - product_title: Tapered Fit Men Light Blue Jeans - score: 3.8475 - url: https://www.flipkart.com/ecko-unltd-tapered-fit-men-light-blue-jeans/p/itm60e479f77deb2?pid=JEAFSKYHHDQ2SDZQ&lid=LSTJEAFSKYHHDQ2SDZQLSCQ5T&marketplace=FLIPKART&srno=b_3_93&otracker=browse&fm=organic&iid=7bfbb0ba-ece9-4236-a8a7-f0f57df4d13f.JEAFSKYHHDQ2SDZQ.SEARCH&ssid=mh6vtqx9mo0000001612104151239
# product_id = JEAFW4DUEGRPEYDR - product_title: Slim Women Light Blue Jeans - score: 3.6510 - url: https://www.flipkart.com/mcj-slim-men-light-blue-jeans/p/itm4fae2733ae2d1?pid=JEAFW4DUEGRPEYDR&lid=LSTJEAFW4DUEGRPEYDREKI1XO&marketplace=FLIPKART&srno=b_1_3&otracker=browse&fm=organic&iid=3a208f72-c01f-4a4c-89c4-5f96c7aa4141.JEAFW4DUEGRPEYDR.SEARCH&ssid=wb7110ywao0000001612114194455
# product_id = JEAFWH29ZSDRZCZ8 - product_title: Slim Women Blue Jeans - score: 3.3465 - url: https://www.flipkart.com/fuel-clothing-slim-men-blue-jeans/p/itm5719fa1724dd8?pid=JEAFWH29ZSDRZCZ8&lid=LSTJEAFWH29ZSDRZCZ8M1ZMKI&marketplace=FLIPKART&srno=b_1_22&otracker=browse&fm=organic&iid=f4f18dbe-2292-41ee-94c8-74a9ccc95946.JEAFWH29ZSDRZCZ8.SEARCH&ssid=cfnkbol1kw0000001612106172360
# product_id = JEAEHGRJSGGYEYYX - product_title: Slim Men Light Blue Jeans - score: 3.3443 - url: https://www.flipkart.com/uber-urban-slim-men-light-blue-jeans/p/itmf3vnfjyzxxbng?pid=JEAEHGRJSGGYEYYX&lid=LSTJEAEHGRJSGGYEYYX4XRZEB&marketplace=FLIPKART&srno=b_4_143&otracker=browse&fm=organic&iid=c5b738a2-aaf1-4fe4-8bd2-eb3a1fd6584c.JEAEHGRJSGGYEYYX.SEARCH&ssid=u74zcvhjuo0000001612413454524
# product_id = JEAFWH29FHYPZFSE - product_title: Slim Women Blue Jeans - score: 3.2812 - url: https://www.flipkart.com/fuel-clothing-slim-men-blue-jeans/p/itm8c19cf56b1320?pid=JEAFWH29FHYPZFSE&lid=LSTJEAFWH29FHYPZFSEWWUMWH&marketplace=FLIPKART&srno=b_1_24&otracker=browse&fm=organic&iid=f4f18dbe-2292-41ee-94c8-74a9ccc95946.JEAFWH29FHYPZFSE.SEARCH&ssid=cfnkbol1kw0000001612106172360
# product_id = JEAFRAQVRVMEUZUZ - product_title: Slim Men Blue Jeans - score: 3.2788 - url: https://www.flipkart.com/levis-slim-men-blue-jeans/p/itm7cf34e312ff71?pid=JEAFRAQVRVMEUZUZ&lid=LSTJEAFRAQVRVMEUZUZQCNTEJ&marketplace=FLIPKART&srno=b_7_261&otracker=browse&fm=organic&iid=a8d16c8e-9c25-4e81-a5c6-52892e5faabf.JEAFRAQVRVMEUZUZ.SEARCH&ssid=a6plfpqpu80000001612111736869
# product_id = JEAFWH29AAGEZANB - product_title: Slim Women Blue Jeans - score: 3.2204 - url: https://www.flipkart.com/fuel-clothing-slim-men-blue-jeans/p/itm124a640242f21?pid=JEAFWH29AAGEZANB&lid=LSTJEAFWH29AAGEZANBKFK99H&marketplace=FLIPKART&srno=b_1_11&otracker=browse&fm=organic&iid=f4f18dbe-2292-41ee-94c8-74a9ccc95946.JEAFWH29AAGEZANB.SEARCH&ssid=cfnkbol1kw0000001612106172360
# product_id = JEAFWH29GZ8MYGGY - product_title: Slim Women Blue Jeans - score: 3.1956 - url: https://www.flipkart.com/fuel-clothing-slim-men-blue-jeans/p/itm15b19ceef8354?pid=JEAFWH29GZ8MYGGY&lid=LSTJEAFWH29GZ8MYGGYPD6FG0&marketplace=FLIPKART&srno=b_1_21&otracker=browse&fm=organic&iid=f4f18dbe-2292-41ee-94c8-74a9ccc95946.JEAFWH29GZ8MYGGY.SEARCH&ssid=cfnkbol1kw0000001612106172360
#
# Query: trousers chino casual men
#
# ======================
# Top 10 results out of 30 for the searched query:
#
# product_id = TROFRBR8YY3UFV2G - product_title: Tapered Men Khaki Cotton Blend Trousers - score: 2.8366 - url: https://www.flipkart.com/levis-tapered-men-khaki-trousers/p/itm535c033b580d8?pid=TROFRBR8YY3UFV2G&lid=LSTTROFRBR8YY3UFV2GHUOR7P&marketplace=FLIPKART&srno=b_2_80&otracker=browse&fm=organic&iid=7db20866-1a4d-4a2a-b693-aac8b0a3aa53.TROFRBR8YY3UFV2G.SEARCH&ssid=7z8q0njtsg0000001612111731089
# product_id = TROFSKFJCHWZF8NQ - product_title: Regular Fit Men Brown Pure Cotton Trousers - score: 2.6711 - url: https://www.flipkart.com/levis-regular-fit-men-brown-trousers/p/itme06d3acfe4838?pid=TROFSKFJCHWZF8NQ&lid=LSTTROFSKFJCHWZF8NQZRJAT2&marketplace=FLIPKART&srno=b_7_254&otracker=browse&fm=organic&iid=a8d16c8e-9c25-4e81-a5c6-52892e5faabf.TROFSKFJCHWZF8NQ.SEARCH&ssid=a6plfpqpu80000001612111736869
# product_id = TROFZQZBZTMBGX7R - product_title: Regular Fit Men Brown Pure Cotton Trousers - score: 2.2952 - url: https://www.flipkart.com/shreeram-regular-fit-men-brown-trousers/p/itm289acff0abe76?pid=TROFZQZBZTMBGX7R&lid=LSTTROFZQZBZTMBGX7R63UNFG&marketplace=FLIPKART&srno=b_1_9&otracker=browse&fm=organic&iid=2bdc2692-6d2e-492e-b861-434264aab9d7.TROFZQZBZTMBGX7R.SEARCH&ssid=z77f9gdxzk0000001612414044956
# product_id = TROFZQZBZAPDHHYQ - product_title: Regular Fit Men Brown Pure Cotton Trousers - score: 2.2952 - url: https://www.flipkart.com/shreeram-regular-fit-men-brown-trousers/p/itm9163a490cb6bb?pid=TROFZQZBZAPDHHYQ&lid=LSTTROFZQZBZAPDHHYQLVVWOT&marketplace=FLIPKART&srno=b_1_6&otracker=browse&fm=organic&iid=2bdc2692-6d2e-492e-b861-434264aab9d7.TROFZQZBZAPDHHYQ.SEARCH&ssid=z77f9gdxzk0000001612414044956
# product_id = TROFZQZBMVN6HQKX - product_title: Regular Fit Men Black Pure Cotton Trousers - score: 2.2952 - url: https://www.flipkart.com/shreeram-regular-fit-men-black-trousers/p/itme8a5688697244?pid=TROFZQZBMVN6HQKX&lid=LSTTROFZQZBMVN6HQKXYEPXK2&marketplace=FLIPKART&srno=b_1_10&otracker=browse&fm=organic&iid=2bdc2692-6d2e-492e-b861-434264aab9d7.TROFZQZBMVN6HQKX.SEARCH&ssid=z77f9gdxzk0000001612414044956
# product_id = TROFZQZBGD5JHDJZ - product_title: Regular Fit Men Blue Pure Cotton Trousers - score: 2.2952 - url: https://www.flipkart.com/shreeram-regular-fit-men-blue-trousers/p/itm90a1e07b87dfd?pid=TROFZQZBGD5JHDJZ&lid=LSTTROFZQZBGD5JHDJZJV5QZR&marketplace=FLIPKART&srno=b_1_11&otracker=browse&fm=organic&iid=2bdc2692-6d2e-492e-b861-434264aab9d7.TROFZQZBGD5JHDJZ.SEARCH&ssid=z77f9gdxzk0000001612414044956
# product_id = TROFZQZBFQXANKSM - product_title: Regular Fit Men White Pure Cotton Trousers - score: 2.2952 - url: https://www.flipkart.com/shreeram-regular-fit-men-white-trousers/p/itm2f4534815d265?pid=TROFZQZBFQXANKSM&lid=LSTTROFZQZBFQXANKSMELBQXC&marketplace=FLIPKART&srno=b_1_12&otracker=browse&fm=organic&iid=2bdc2692-6d2e-492e-b861-434264aab9d7.TROFZQZBFQXANKSM.SEARCH&ssid=z77f9gdxzk0000001612414044956
# product_id = TROFZQZB5YVN5GNW - product_title: Regular Fit Men Grey Pure Cotton Trousers - score: 2.2952 - url: https://www.flipkart.com/shreeram-regular-fit-men-grey-trousers/p/itm8aa512d706762?pid=TROFZQZB5YVN5GNW&lid=LSTTROFZQZB5YVN5GNWCEHVFO&marketplace=FLIPKART&srno=b_1_4&otracker=browse&fm=organic&iid=2bdc2692-6d2e-492e-b861-434264aab9d7.TROFZQZB5YVN5GNW.SEARCH&ssid=z77f9gdxzk0000001612414044956
# product_id = TROFZEYCMFEZZ7PP - product_title: Slim Fit Men Brown Pure Cotton Trousers - score: 1.9474 - url: https://www.flipkart.com/ksx-slim-fit-men-brown-trousers/p/itmda591169cec9e?pid=TROFZEYCMFEZZ7PP&lid=LSTTROFZEYCMFEZZ7PPXE2RLW&marketplace=FLIPKART&srno=b_1_37&otracker=browse&fm=organic&iid=eaa2a136-9312-4283-a917-65a04e19c0cd.TROFZEYCMFEZZ7PP.SEARCH&ssid=elmcrypbnk0000001612111125650
# product_id = SHTFCCRGR4YBGTGM - product_title: Men Slim Fit Solid Spread Collar Casual Shirt - score: 1.8411 - url: https://www.flipkart.com/adam-parker-men-solid-casual-blue-shirt/p/itmfcctxwgxuhffb?pid=SHTFCCRGR4YBGTGM&lid=LSTSHTFCCRGR4YBGTGMDV1NZJ&marketplace=FLIPKART&srno=b_3_83&otracker=browse&fm=organic&iid=a3cad1e8-8c15-45dd-a393-177ee3e7c24f.SHTFCCRGR4YBGTGM.SEARCH&ssid=09efakbxog0000001612094214810
#
# Query: black sports shoes
#
# ======================
# Top 10 results out of 60 for the searched query:
#
# product_id = SHOFN3EJHXHGSGUC - product_title: RS-7250 Running Shoes For Men  (Black) - score: 8.7852 - url: https://www.flipkart.com/vector-x-rs-7250-running-shoes-men/p/itm315827b1dcd91?pid=SHOFN3EJHXHGSGUC&lid=LSTSHOFN3EJHXHGSGUCGWFHSS&marketplace=FLIPKART&srno=b_5_189&otracker=nmenu_sub_Men_0_Footwear&fm=organic&iid=2c9c6405-15f7-4765-be59-536d21002294.SHOFN3EJHXHGSGUC.SEARCH&ssid=z6yjmdcc8w0000001612688550527
# product_id = SHOFN3EJZKBG6QUF - product_title: JAGUAR Football Shoes For Women  (Red, Black) - score: 8.3345 - url: https://www.flipkart.com/vector-x-jaguar-football-shoes-men/p/itmb9b13375a136c?pid=SHOFN3EJZKBG6QUF&lid=LSTSHOFN3EJZKBG6QUFNSOSIE&marketplace=FLIPKART&srno=b_2_62&otracker=nmenu_sub_Men_0_Footwear&fm=organic&iid=ed342989-9f17-43c2-b620-87aa4485e449.SHOFN3EJZKBG6QUF.SEARCH&ssid=3u6pawgow00000001612688548473
# product_id = SHOFUH52V5AVNHMN - product_title: Loafers For Men  (Black) - score: 5.3780 - url: https://www.flipkart.com/bonexy-loafers-men/p/itm1e009dae6f7b7?pid=SHOFUH52V5AVNHMN&lid=LSTSHOFUH52V5AVNHMNOFKK8J&marketplace=FLIPKART&srno=b_3_88&otracker=nmenu_sub_Men_0_Footwear&fm=organic&iid=808ae14d-03e8-4469-804b-6525b9271ee1.SHOFUH52V5AVNHMN.SEARCH&ssid=zh5c7ofn9s0000001612687775142
# product_id = SHOFX2G6FHVNAHZN - product_title: Loafers For Women  (Black) - score: 5.2340 - url: https://www.flipkart.com/bonexy-loafers-men/p/itm23d387bf5b8dc?pid=SHOFX2G6FHVNAHZN&lid=LSTSHOFX2G6FHVNAHZNOFD874&marketplace=FLIPKART&srno=b_1_5&otracker=nmenu_sub_Men_0_Footwear&fm=organic&iid=60bce454-5fce-46d0-997f-6bf4aafc9c3d.SHOFX2G6FHVNAHZN.SEARCH&ssid=9a2pecj24w0000001612687773586
# product_id = SHOFVXG5XR59AFTH - product_title: Lace Up For Men  (Black) - score: 5.2340 - url: https://www.flipkart.com/bonexy-lace-up-men/p/itm6225a24faff46?pid=SHOFVXG5XR59AFTH&lid=LSTSHOFVXG5XR59AFTHYZWSY7&marketplace=FLIPKART&srno=b_3_93&otracker=nmenu_sub_Men_0_Footwear&fm=organic&iid=808ae14d-03e8-4469-804b-6525b9271ee1.SHOFVXG5XR59AFTH.SEARCH&ssid=zh5c7ofn9s0000001612687775142
# product_id = SHOFVJX2TP8FRR7P - product_title: Lace Up For Men  (Black) - score: 5.2340 - url: https://www.flipkart.com/bonexy-lace-up-men/p/itmfe9bb2538a268?pid=SHOFVJX2TP8FRR7P&lid=LSTSHOFVJX2TP8FRR7PDUS5IB&marketplace=FLIPKART&srno=b_3_115&otracker=nmenu_sub_Men_0_Footwear&fm=organic&iid=808ae14d-03e8-4469-804b-6525b9271ee1.SHOFVJX2TP8FRR7P.SEARCH&ssid=zh5c7ofn9s0000001612687775142
# product_id = SHOFVHY8MAYUPTZF - product_title: Loafers For Men  (Black) - score: 5.2340 - url: https://www.flipkart.com/bonexy-loafers-men/p/itmf976e23f2b92e?pid=SHOFVHY8MAYUPTZF&lid=LSTSHOFVHY8MAYUPTZFB4ADRT&marketplace=FLIPKART&srno=b_3_97&otracker=nmenu_sub_Men_0_Footwear&fm=organic&iid=808ae14d-03e8-4469-804b-6525b9271ee1.SHOFVHY8MAYUPTZF.SEARCH&ssid=zh5c7ofn9s0000001612687775142
# product_id = SHOE7TZFE2TCNPH5 - product_title: Sports Shoes For Women  (Black, Yellow) - score: 4.6496 - url: https://www.flipkart.com/vector-x-sports-shoes-men/p/itmf3x9nawzud6sc?pid=SHOE7TZFE2TCNPH5&lid=LSTSHOE7TZFE2TCNPH5ON7MYR&marketplace=FLIPKART&srno=b_4_150&otracker=nmenu_sub_Men_0_Footwear&fm=organic&iid=39cd0f32-17f1-4b96-b66f-031eb5a9fa63.SHOE7TZFE2TCNPH5.SEARCH&ssid=oxr1fcm7ps0000001612688549818
# product_id = SHOFJGUAGAVDZ8CJ - product_title: Slip On For Men  (Black) - score: 4.6052 - url: https://www.flipkart.com/bonexy-slip-men/p/itmce5b9a96fef27?pid=SHOFJGUAGAVDZ8CJ&lid=LSTSHOFJGUAGAVDZ8CJ27DXTT&marketplace=FLIPKART&srno=b_2_62&otracker=nmenu_sub_Men_0_Footwear&fm=organic&iid=88d4419d-60b6-4a7b-83d5-083647273b93.SHOFJGUAGAVDZ8CJ.SEARCH&ssid=kok955yw6o0000001612687774372
# product_id = SHOEHEJBDHMQHASJ - product_title: Blaze Football Shoes For Men  (Black) - score: 4.5498 - url: https://www.flipkart.com/vector-x-blaze-football-shoes-men/p/itmf3xtxe7uvwcbd?pid=SHOEHEJBDHMQHASJ&lid=LSTSHOEHEJBDHMQHASJ1TRL7K&marketplace=FLIPKART&srno=b_2_71&otracker=nmenu_sub_Men_0_Footwear&fm=organic&iid=ed342989-9f17-43c2-b620-87aa4485e449.SHOEHEJBDHMQHASJ.SEARCH&ssid=3u6pawgow00000001612688548473
#
# Query: fancy t-shirt
#
# ======================
# Top 10 results out of 551 for the searched query:
#
# product_id = TSHFRTE97H8QCQYN - product_title: Printed Women Round Neck White T-Shirt - score: 2.7266 - url: https://www.flipkart.com/breakbounce-printed-men-round-neck-white-t-shirt/p/itmafca2ce44d506?pid=TSHFRTE97H8QCQYN&lid=LSTTSHFRTE97H8QCQYNHJBIHF&marketplace=FLIPKART&srno=b_5_173&otracker=browse&fm=organic&iid=89b8b0d2-08db-40dd-a8a1-93929dcdc19d.TSHFRTE97H8QCQYN.SEARCH&ssid=9jcdti7a9c0000001612099602338
# product_id = TSHFZR3JJCU6UZM3 - product_title: Printed Women Round Neck Black T-Shirt - score: 2.0179 - url: https://www.flipkart.com/humanity-originals-printed-men-round-neck-black-t-shirt/p/itm6f82f50dc006c?pid=TSHFZR3JJCU6UZM3&lid=LSTTSHFZR3JJCU6UZM3RUQEYM&marketplace=FLIPKART&srno=b_1_32&otracker=browse&fm=organic&iid=f8a86569-eb59-457b-8314-f81309b46ec9.TSHFZR3JJCU6UZM3.SEARCH&ssid=m6kznfve0w0000001612108048404
# product_id = TSHFZR3GRSZHDKT5 - product_title: Printed Women Round Neck Black T-Shirt - score: 2.0179 - url: https://www.flipkart.com/humanity-originals-printed-men-round-neck-black-t-shirt/p/itm9c0ceb39e13b0?pid=TSHFZR3GRSZHDKT5&lid=LSTTSHFZR3GRSZHDKT5GLFJ9G&marketplace=FLIPKART&srno=b_1_9&otracker=browse&fm=organic&iid=f8a86569-eb59-457b-8314-f81309b46ec9.TSHFZR3GRSZHDKT5.SEARCH&ssid=m6kznfve0w0000001612108048404
# product_id = TSHFZR3DGG7HFQQ4 - product_title: Printed Men Round Neck Black T-Shirt - score: 2.0179 - url: https://www.flipkart.com/humanity-originals-printed-men-round-neck-black-t-shirt/p/itm62e87ba7c585f?pid=TSHFZR3DGG7HFQQ4&lid=LSTTSHFZR3DGG7HFQQ4IVD5EX&marketplace=FLIPKART&srno=b_1_25&otracker=browse&fm=organic&iid=f8a86569-eb59-457b-8314-f81309b46ec9.TSHFZR3DGG7HFQQ4.SEARCH&ssid=m6kznfve0w0000001612108048404
# product_id = TSHFZR3CZUKEUMQF - product_title: Printed Men Round Neck Black T-Shirt - score: 2.0179 - url: https://www.flipkart.com/humanity-originals-printed-men-round-neck-black-t-shirt/p/itm142453716be32?pid=TSHFZR3CZUKEUMQF&lid=LSTTSHFZR3CZUKEUMQFLXAPIT&marketplace=FLIPKART&srno=b_1_15&otracker=browse&fm=organic&iid=f8a86569-eb59-457b-8314-f81309b46ec9.TSHFZR3CZUKEUMQF.SEARCH&ssid=m6kznfve0w0000001612108048404
# product_id = TSHFZR3CKNSPZZE7 - product_title: Printed Men Round Neck Black T-Shirt - score: 2.0179 - url: https://www.flipkart.com/humanity-originals-printed-men-round-neck-black-t-shirt/p/itm95840bc8b5660?pid=TSHFZR3CKNSPZZE7&lid=LSTTSHFZR3CKNSPZZE7NVQYY5&marketplace=FLIPKART&srno=b_1_21&otracker=browse&fm=organic&iid=f8a86569-eb59-457b-8314-f81309b46ec9.TSHFZR3CKNSPZZE7.SEARCH&ssid=m6kznfve0w0000001612108048404
# product_id = TSHFZR3C23G3ZB8K - product_title: Printed Men Round Neck Black T-Shirt - score: 2.0179 - url: https://www.flipkart.com/humanity-originals-printed-men-round-neck-black-t-shirt/p/itmcd5a9b725b44d?pid=TSHFZR3C23G3ZB8K&lid=LSTTSHFZR3C23G3ZB8KV9KORQ&marketplace=FLIPKART&srno=b_1_22&otracker=browse&fm=organic&iid=f8a86569-eb59-457b-8314-f81309b46ec9.TSHFZR3C23G3ZB8K.SEARCH&ssid=m6kznfve0w0000001612108048404
# product_id = TSHFZR3BNGUSD5Z5 - product_title: Printed Men Round Neck Black T-Shirt - score: 2.0179 - url: https://www.flipkart.com/humanity-originals-printed-men-round-neck-black-t-shirt/p/itm1319abdb3cade?pid=TSHFZR3BNGUSD5Z5&lid=LSTTSHFZR3BNGUSD5Z5FVF89A&marketplace=FLIPKART&srno=b_1_23&otracker=browse&fm=organic&iid=f8a86569-eb59-457b-8314-f81309b46ec9.TSHFZR3BNGUSD5Z5.SEARCH&ssid=m6kznfve0w0000001612108048404
# product_id = TSHFZPENHCAQQWCR - product_title: Printed Women Round Neck Yellow, Red T-Shirt  (Pack of 2) - score: 1.9343 - url: https://www.flipkart.com/vibrant-vesture-printed-men-round-neck-yellow-red-t-shirt/p/itm56d1349dcab46?pid=TSHFZPENHCAQQWCR&lid=LSTTSHFZPENHCAQQWCRB951FO&marketplace=FLIPKART&srno=b_1_7&otracker=browse&fm=organic&iid=b8c2969c-4287-4048-8b20-b40af52f9a71.TSHFZPENHCAQQWCR.SEARCH&ssid=kofqgn0atc0000001612414456957
# product_id = TSHFZPENCUGXACSY - product_title: Printed Men Round Neck Orange, Pink T-Shirt  (Pack of 2) - score: 1.9343 - url: https://www.flipkart.com/vibrant-vesture-printed-men-round-neck-orange-pink-t-shirt/p/itmf8718298a548a?pid=TSHFZPENCUGXACSY&lid=LSTTSHFZPENCUGXACSYJNLXFG&marketplace=FLIPKART&srno=b_1_17&otracker=browse&fm=organic&iid=b8c2969c-4287-4048-8b20-b40af52f9a71.TSHFZPENCUGXACSY.SEARCH&ssid=kofqgn0atc0000001612414456957

# %% [markdown]
# # Part 2: Evaluation

# %% [markdown]
# ## 2.1 Implement the evaluation metrics

# %%
def precision_at_k(doc_score, y_score, k=10):
    """
    Parameters
    ----------
    doc_score: dict mapping doc_id to ground truth relevance (0 or 1)
    y_score: list of tuples (doc_id, predicted_score)
    k : number of docs to consider

    Returns
    -------
    precision @k : float
    """
    sorted_docs = sorted(y_score, key=lambda x: x[1], reverse=True)

    top_k_docs = [doc_id for doc_id, _ in sorted_docs[:k]]

    relevant = sum(doc_score.get(doc_id, 0) == 1 for doc_id in top_k_docs)

    return float(relevant) / k

# %%
def recall_at_k(doc_score, y_score, k=10):
    """
    Parameters
    ----------
    doc_score: dict mapping doc_id to ground truth relevance (0 or 1)
    y_score: list of tuples (doc_id, predicted_score)
    k : number of docs to consider

    Returns
    -------
    recall @k : float
    """
    sorted_docs = sorted(y_score, key=lambda x: x[1], reverse=True)

    top_k_docs = [doc_id for doc_id, _ in sorted_docs[:k]]

    relevant_retrieved = sum(doc_score.get(doc_id, 0) == 1 for doc_id in top_k_docs)

    total_relevant = sum(1 for relevance in doc_score.values() if relevance == 1)

    if total_relevant == 0:
        return 0.0

    return float(relevant_retrieved) / total_relevant

# %%
def avg_precision_at_k(doc_score, y_score, k=10):
    """
    Parameters
    ----------
    doc_score: dict mapping doc_id to ground truth relevance (0 or 1)
    y_score: list of tuples (doc_id, predicted_score)
    k : number of docs to consider

    Returns
    -------
    average precision @k : float
    """
    sorted_docs = sorted(y_score, key=lambda x: x[1], reverse=True)
    top_k = sorted_docs[:k]

    relevant = 0
    precision_sum = 0.0

    for i, (pid, _) in enumerate(top_k, start=1):
        if doc_score.get(pid, 0) == 1:
            relevant += 1
            precision_sum += relevant / i

    if relevant == 0:
        return 0.0

    return precision_sum / relevant

# %%
def f1_score_at_k(doc_score, y_score, k=10):
    """
    Parameters
    ----------
    doc_score: dict mapping doc_id to ground truth relevance (0 or 1)
    y_score: list of tuples (doc_id, predicted_score)
    k : number of docs to consider

    Returns
    -------
    F1-score @k : float
    """
    sorted_docs = sorted(y_score, key=lambda x: x[1], reverse=True)
    top_k = sorted_docs[:k]

    relevant_retrieved = sum(doc_score.get(pid, 0) == 1 for pid, _ in top_k)
    total_relevant = sum(1 for rel in doc_score.values() if rel == 1)

    precision = relevant_retrieved / k if k > 0 else 0
    recall = relevant_retrieved / total_relevant if total_relevant > 0 else 0

    if precision + recall == 0:
        return 0.0

    return 2 * (precision * recall) / (precision + recall)

# %%
def map_at_k(all_doc_scores, all_y_scores, k=10):
    """
    Parameters
    ----------
    all_doc_scores: list of dicts mapping doc_id to ground truth relevance (0 or 1)
    all_y_scores: list of lists of tuples (doc_id, predicted_score)
    k : number of docs to consider

    Returns
    -------
    mean average precision @k : float
    list of average precision scores per query : list
    """
    ap_list = []
    for doc_score, y_score in zip(all_doc_scores, all_y_scores):
        ap_list.append(avg_precision_at_k(doc_score, y_score, k))
    return np.mean(ap_list), ap_list

# %%
def rr_at_k(doc_score, y_score, k=10):
    """
    Parameters
    ----------
    doc_score: dict mapping doc_id to ground truth relevance (0 or 1)
    y_score: list of tuples (doc_id, predicted_score)
    k : number of docs to consider

    Returns
    -------
    reciprocal rank @k : float
    """
    sorted_docs = sorted(y_score, key=lambda x: x[1], reverse=True)
    top_k = sorted_docs[:k]

    for rank, (pid, _) in enumerate(top_k, start=1):
        if doc_score.get(pid, 0) == 1:
            return 1.0 / rank
    return 0.0

# %%
def dcg_at_k(doc_score, y_score, k=10):
    """
    Parameters
    ----------
    doc_score: dict mapping doc_id to ground truth relevance (0 or 1)
    y_score: list of tuples (doc_id, predicted_score)
    k : number of docs to consider

    Returns
    -------
    discounted cumulative gain @k : float
    """
    sorted_docs = sorted(y_score, key=lambda x: x[1], reverse=True)
    top_k = sorted_docs[:k]

    gains = [(2 ** doc_score.get(pid, 0) - 1) for pid, _ in top_k]
    discounts = np.log2(np.arange(len(gains)) + 2)

    return np.sum(np.array(gains) / discounts)

def ndcg_at_k(doc_score, y_score, k=10):
    """
    Parameters
    ----------
    doc_score: dict mapping doc_id to ground truth relevance (0 or 1)
    y_score: list of tuples (doc_id, predicted_score)
    k : number of docs to consider

    Returns
    -------
    normalized discounted cumulative gain @k : float
    """
    ideal_y_score = [(pid, doc_score.get(pid, 0)) for pid in doc_score]
    ideal_dcg = dcg_at_k(doc_score, ideal_y_score, k)
    if ideal_dcg == 0:
        return 0.0
    return np.round(dcg_at_k(doc_score, y_score, k) / ideal_dcg, 4)

# %% [markdown]
# # 2.2. Apply the evaluation metrics

# %%
# Read validation labels
df = pd.read_csv("../../data/validation_labels.csv")

# Define example queries
query_texts = {
    1: "women full sleeve sweatshirt cotton",
    2: "men slim jeans blue"
}

# Preprocess queries
processed_queries = {qid: build_terms(text) for qid, text in query_texts.items()}

# Create relevance maps for each query
relevance_maps = {}
for query_id, group in df.groupby("query_id"):
    processed_query = tuple(processed_queries[query_id])
    relevance_maps[processed_query] = {
        row["pid"]: int(row["labels"]) for _, row in group.iterrows()
    }

# Evaluate each query
for query_id, terms in processed_queries.items():
    query_key = tuple(terms)
    ranked_prods, prod_scores = rank_documents(
        terms,
        list(relevance_maps[query_key].keys()),
        index,
        idf,
        tf,
        title_index
    )

    # Pair product ids with their scores
    y_score = [(pid, score) for score, pid in prod_scores]
    doc_score = relevance_maps[query_key]

    # Compute evaluation metrics
    p_at_10 = round(precision_at_k(doc_score, y_score, k=10), 3)
    r_at_10 = round(recall_at_k(doc_score, y_score, k=10), 3)
    ap_at_10 = round(avg_precision_at_k(doc_score, y_score, k=10), 3)
    f1_at_10 = round(f1_score_at_k(doc_score, y_score, k=10), 3)
    rr = round(rr_at_k(doc_score, y_score, k=10), 3)
    ndcg = round(ndcg_at_k(doc_score, y_score, k=10), 3)

    # Print results in a readable way
    print("-" * 50)
    print(f"Query {query_id}: {' '.join(terms)}")
    print(f"Precision@10 : {p_at_10}")
    print(f"Recall@10    : {r_at_10}")
    print(f"Avg Precision: {ap_at_10}")
    print(f"F1-Score@10  : {f1_at_10}")
    print(f"Reciprocal R.: {rr}")
    print(f"NDCG@10      : {ndcg}")
    print("-" * 50)

# Evaluate mean average precision for all queries
all_doc_scores = []
all_y_scores = []

for query_id, terms in processed_queries.items():
    query_key = tuple(terms)
    ranked_prods, prod_scores = rank_documents(
        terms,
        list(relevance_maps[query_key].keys()),
        index,
        idf,
        tf,
        title_index
    )

    y_score = [(pid, score) for score, pid in prod_scores]
    doc_score = relevance_maps[query_key]

    all_doc_scores.append(doc_score)
    all_y_scores.append(y_score)

# Compute MAP@10
mean_ap, ap_list = map_at_k(all_doc_scores, all_y_scores, k=10)

# Print MAP results clearly
print("-" * 50)
print("Overall Performance Summary")
print(f"Mean Average Precision (MAP@10): {round(mean_ap, 3)}")
print("Average precision per query:", " ".join(str(round(ap, 3)) for ap in ap_list))
print("-" * 50)
# Out:
# --------------------------------------------------
# Query 1: women full sleev sweatshirt cotton
# Precision@10 : 1.0
# Recall@10    : 0.769
# Avg Precision: 1.0
# F1-Score@10  : 0.87
# Reciprocal R.: 1.0
# NDCG@10      : 1.0
# --------------------------------------------------
# --------------------------------------------------
# Query 2: men slim jean blue
# Precision@10 : 0.6
# Recall@10    : 0.6
# Avg Precision: 0.68
# F1-Score@10  : 0.6
# Reciprocal R.: 1.0
# NDCG@10      : 0.615
# --------------------------------------------------
# --------------------------------------------------
# Overall Performance Summary
# Mean Average Precision (MAP@10): 0.84
# Average precision per query: 1.0 0.68
# --------------------------------------------------

# %%
def evaluate_queries(df, query_texts, index, idf, tf, title_index, k=10):
    """
    Evaluate a set of queries and print per-query metrics + MAP@k.
    """

    # Preprocess queries
    processed_queries = {qid: build_terms(text) for qid, text in query_texts.items()}

    # Build relevance maps
    relevance_maps = {}
    for query_id, group in df.groupby("query_id"):
        processed_query = tuple(processed_queries[query_id])
        relevance_maps[processed_query] = {
            row["pid"]: int(row["labels"]) for _, row in group.iterrows()
        }

    # Evaluate each query
    all_doc_scores = []
    all_y_scores = []

    for query_id, terms in processed_queries.items():
        query_key = tuple(terms)
        ranked_prods, prod_scores = rank_documents(
            terms,
            list(relevance_maps[query_key].keys()),
            index,
            idf,
            tf,
            title_index
        )

        y_score = [(pid, score) for score, pid in prod_scores]
        doc_score = relevance_maps[query_key]

        # Metrics
        p_at_10 = round(precision_at_k(doc_score, y_score, k), 3)
        r_at_10 = round(recall_at_k(doc_score, y_score, k), 3)
        ap_at_10 = round(avg_precision_at_k(doc_score, y_score, k), 3)
        f1_at_10 = round(f1_score_at_k(doc_score, y_score, k), 3)
        rr = round(rr_at_k(doc_score, y_score, k), 3)
        ndcg = round(ndcg_at_k(doc_score, y_score, k), 3)

        print("-" * 55)
        print(f"Query {query_id}: {' '.join(terms)}")
        print(f"Precision@{k}       : {p_at_10}")
        print(f"Recall@{k}          : {r_at_10}")
        print(f"Avg Precision@{k}   : {ap_at_10}")
        print(f"F1-Score@{k}        : {f1_at_10}")
        print(f"Reciprocal Rank@{k} : {rr}")
        print(f"NDCG@{k}            : {ndcg}")
        print("-" * 55)

        all_doc_scores.append(doc_score)
        all_y_scores.append(y_score)

    # Compute and print MAP@k
    mean_ap, ap_list = map_at_k(all_doc_scores, all_y_scores, k)
    print("\nOverall Performance Summary")
    print("=" * 55)
    print(f"Mean Average Precision (MAP@{k}): {round(mean_ap, 3)}")
    print("Average precision per query   :", " ".join(str(round(ap, 3)) for ap in ap_list))
    print("=" * 55)

# %%
df = pd.read_csv("../../data/student_validation_labels.csv")

query_texts = {
    1: "casual half sleeve polo shirt for men",
    2: "light blue jeans slim fit",
    3: "trousers chino casual men",
    4: "black sports shoes",
    5: "fancy t-shirt"
}

evaluate_queries(df, query_texts, index, idf, tf, title_index, k=5)
# Out:
# -------------------------------------------------------
# Query 1: casual half sleev polo shirt men
# Precision@5       : 1.0
# Recall@5          : 0.5
# Avg Precision@5   : 1.0
# F1-Score@5        : 0.667
# Reciprocal Rank@5 : 1.0
# NDCG@5            : 1.0
# -------------------------------------------------------
# -------------------------------------------------------
# Query 2: light blue jean slim fit
# Precision@5       : 1.0
# Recall@5          : 0.625
# Avg Precision@5   : 1.0
# F1-Score@5        : 0.769
# Reciprocal Rank@5 : 1.0
# NDCG@5            : 1.0
# -------------------------------------------------------
# -------------------------------------------------------
# Query 3: trouser chino casual men
# Precision@5       : 1.0
# Recall@5          : 0.556
# Avg Precision@5   : 1.0
# F1-Score@5        : 0.714
# Reciprocal Rank@5 : 1.0
# NDCG@5            : 1.0
# -------------------------------------------------------
# -------------------------------------------------------
# Query 4: black sport shoe
# Precision@5       : 0.2
# Recall@5          : 0.5
# Avg Precision@5   : 1.0
# F1-Score@5        : 0.286
# Reciprocal Rank@5 : 1.0
# NDCG@5            : 0.613
# -------------------------------------------------------
# -------------------------------------------------------
# Query 5: fanci t-shirt
# Precision@5       : 0.8
# Recall@5          : 1.0
# Avg Precision@5   : 0.804
# F1-Score@5        : 0.889
# Reciprocal Rank@5 : 1.0
# NDCG@5            : 0.905
# -------------------------------------------------------
#
# Overall Performance Summary
# =======================================================
# Mean Average Precision (MAP@5): 0.961
# Average precision per query   : 1.0 1.0 1.0 1.0 0.804
# =======================================================
