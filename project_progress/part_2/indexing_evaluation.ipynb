# %% [markdown]
# # Part 1: Indexing

# %% [markdown]
# #### Imports

# %%
import nltk
import json
from collections import defaultdict
from array import array
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
import math
import numpy as np
import collections
from numpy import linalg as la
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# from wordcloud import WordCloud
from collections import Counter

# %% [markdown]
# #### Useful code from part 1

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\yuxia\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def remove_punctuation(text):
    cleaned = ""
    for char in text:
        if char.isalnum() or char.isspace() or char == "-":
            cleaned += char
        else:
            cleaned += " "  # Replace punctuation with space
    return cleaned

# %%
products_path = '../../data/fashion_products_dataset.json'
with open(products_path, "r", encoding="utf-8") as f:
    products = pd.read_json(products_path)

def build_terms(line):
    """
    Preprocess a line:
    ●  Removing stop words 
    ●  Tokenization 
    ●  Removing punctuation marks 
    ●  Stemming 
    ●  Transforming to lowercase

    Argument:
    line -- string (text) to be preprocessed

    Returns:
    line - a list of tokens corresponding to the input text after the preprocessing
    """

    stemmer = PorterStemmer()
    stop_words = set(stopwords.words("english"))
    line = line.lower()
    line = remove_punctuation(line)
    line = line.split()
    line = [x for x in line if x not in stop_words]
    line = [stemmer.stem(word) for word in line]
    return line

def get_products_information(products_df):
    elements = ["pid", "title", "description", "brand", "category", "sub_category", 
                "product_details", "seller", "out_of_stock", "selling_price", 
                "discount", "actual_price", "average_rating", "url"]
    
    products_df = products_df[elements]
    
    return products_df

products = get_products_information(products)
products["processed_title"] = products["title"].apply(build_terms)
products["processed_description"] = products["description"].apply(build_terms)
products['cat_subcat'] = products['category'] + ": " + products['sub_category']

# %% [markdown]
# ## 1. Build inverted index

# %% [markdown]
# We join the words in the processed titles and the processed descriptions for each product

# %%
products["title_description"] = products["processed_title"] + products["processed_description"]
display(products.head(5))
# Out:
#                 pid                                title  \
# 0  TKPFCZ9EA7H5FYZH   Solid Women Multicolor Track Pants
# 1  TKPFCZ9EJZV2UVRZ           Solid Men Blue Track Pants
# 2  TKPFCZ9EHFCY5Z4Y     Solid Men Multicolor Track Pants
# 3  TKPFCZ9ESZZ7YWEF   Solid Women Multicolor Track Pants
# 4  TKPFCZ9EVXKBSUD7  Solid Women Brown, Grey Track Pants
#
#                                          description brand  \
# 0  Yorker trackpants made from 100% rich combed c...  York
# 1  Yorker trackpants made from 100% rich combed c...  York
# 2  Yorker trackpants made from 100% rich combed c...  York
# 3  Yorker trackpants made from 100% rich combed c...  York
# 4  Yorker trackpants made from 100% rich combed c...  York
#
#                    category sub_category  \
# 0  Clothing and Accessories   Bottomwear
# 1  Clothing and Accessories   Bottomwear
# 2  Clothing and Accessories   Bottomwear
# 3  Clothing and Accessories   Bottomwear
# 4  Clothing and Accessories   Bottomwear
#
#                                      product_details             seller  \
# 0  [{'Style Code': '1005COMBO2'}, {'Closure': 'El...  Shyam Enterprises
# 1  [{'Style Code': '1005BLUE'}, {'Closure': 'Draw...  Shyam Enterprises
# 2  [{'Style Code': '1005COMBO4'}, {'Closure': 'El...  Shyam Enterprises
# 3  [{'Style Code': '1005COMBO3'}, {'Closure': 'El...  Shyam Enterprises
# 4  [{'Style Code': '1005COMBO1'}, {'Closure': 'Dr...  Shyam Enterprises
#
#    out_of_stock selling_price discount actual_price average_rating  \
# 0         False           921  69% off        2,999            3.9
# 1         False           499  66% off        1,499            3.9
# 2         False           931  68% off        2,999            3.9
# 3         False           911  69% off        2,999            3.9
# 4         False           943  68% off        2,999            3.9
#
#                                                  url  \
# 0  https://www.flipkart.com/yorker-solid-men-mult...
# 1  https://www.flipkart.com/yorker-solid-men-blue...
# 2  https://www.flipkart.com/yorker-solid-men-mult...
# 3  https://www.flipkart.com/yorker-solid-men-mult...
# 4  https://www.flipkart.com/yorker-solid-men-brow...
#
#                             processed_title  \
# 0   [solid, women, multicolor, track, pant]
# 1           [solid, men, blue, track, pant]
# 2     [solid, men, multicolor, track, pant]
# 3   [solid, women, multicolor, track, pant]
# 4  [solid, women, brown, grey, track, pant]
#
#                                processed_description  \
# 0  [yorker, trackpant, made, 100, rich, comb, cot...
# 1  [yorker, trackpant, made, 100, rich, comb, cot...
# 2  [yorker, trackpant, made, 100, rich, comb, cot...
# 3  [yorker, trackpant, made, 100, rich, comb, cot...
# 4  [yorker, trackpant, made, 100, rich, comb, cot...
#
#                              cat_subcat  \
# 0  Clothing and Accessories: Bottomwear
# 1  Clothing and Accessories: Bottomwear
# 2  Clothing and Accessories: Bottomwear
# 3  Clothing and Accessories: Bottomwear
# 4  Clothing and Accessories: Bottomwear
#
#                                    title_description
# 0  [solid, women, multicolor, track, pant, yorker...
# 1  [solid, men, blue, track, pant, yorker, trackp...
# 2  [solid, men, multicolor, track, pant, yorker, ...
# 3  [solid, women, multicolor, track, pant, yorker...
# 4  [solid, women, brown, grey, track, pant, yorke...

# %%
def create_index(products):
    """
    Implement the inverted index.

    Argument:
    products - collection of products, where each product contains the list 
               of words for the title and description of the product.

    Returns:
    index - the inverted index (implemented through a Python dictionary) containing terms 
            as keys and the corresponding list of documents where these keys appears.
    """
    index = defaultdict(list)
    for i in range(len(products)):
        pid = products.iloc[i]["pid"]
        words = products.iloc[i]["title_description"]
        unique_terms = set(words)
        for term in unique_terms:
            index[term].append(pid)

    return dict(index)

# %%
inverted_index = create_index(products)
num_products = products.shape[0]
for i, (term, doc_list) in enumerate(inverted_index.items()):
    print(f"{term} DF = {round(len(doc_list)/num_products, 3)} : {doc_list}")
    if i == 9:
        break
# Out:
# year DF = 0.016 : ['TKPFCZ9EA7H5FYZH', 'TKPFCZ9EJZV2UVRZ', 'TKPFCZ9EHFCY5Z4Y', 'TKPFCZ9ESZZ7YWEF', 'TKPFCZ9EVXKBSUD7', 'TKPFCZ9EFK9DNWDA', 'TKPFDABN3GXYPFHE', 'TKPFCZ9ESGZYT8NH', 'TKPFCZ9DYU33FFXS', 'TKPFDABN4NQFVKZY', 'TKPFCZ9ENWGMX23W', 'TKPFCZ9EHCNAPKPU', 'TKPFDACEXAWUHGR7', 'TKPFCZ9ETR6YVXNG', 'TKPFD3K6K5TNYZGF', 'TKPFCZ9EGGYENTZS', 'TKPFD3K6ZMN79MPH', 'TKPFD3K6UZBYDZNY', 'TKPFD3K62JB9PEMR', 'TKPFCZ9EZDPZR5AH', 'TKPFCZ9EVM2GZ4GF', 'TKPFCZ9E2UC3DR3F', 'TKPFCZ9ECDYYDNKA', 'CTPFVZHSA7G4PFC5', 'CTPFVZD8CNSZ3AMR', 'CTPFVQNNHGYFTGFN', 'CTPFVZT3UFN99ZTH', 'CTPFVSU7CXFCXEHD', 'CTPFVZGRKPGSFPUU', 'CTPFVZT7EFZWVRUP', 'CTPFVZT2GYAVYEE6', 'CTPFVZHFTSBTMH9M', 'CTPFVZTPGHGVFCFE', 'CTPFVSSQHD96FH9Z', 'CTPFVZEYHCRQ27Y2', 'CTPFVZFYR8KGYYBJ', 'CTPFW3W97JMQVBYG', 'CTPFW3VX6NGRNZUE', 'CTPFVQNGFCRGYK2H', 'CTPFVPN4CUY6QZXD', 'CTPFVPMUAHEJX8EW', 'CTPFVPMZV7RCDNVR', 'CTPFVZT46SYT5GTB', 'CTPFVZT9ZYJB4WJZ', 'CTPFVTZ9GYNEDU54', 'CTPFVZTZNFBGXUMD', 'CTPFVZTBCHWHDMGJ', 'CTPFVQSGZGPHUEFX', 'CTPFVZTBN4GRZKXH', 'CTPFVPKKWBZUCH7Y', 'CTPFVZGY4PQHQNFH', 'CTPFVPH2JGZRW6FV', 'CTPFVPKJUJDPNCCR', 'CTPFVPJZKBVGK2FV', 'CTPFVSXYFFS9XHDG', 'CTPFVZHVZVU4VQW9', 'CTPFVZT6GAFZ7BJX', 'CTPFVZT2F5UPM4YT', 'CTPFVPFPUWYQC9M5', 'CTPFVPFPHGWGF6DS', 'CTPFVHUJMZSAHPFG', 'CTPFVPFV43SVFUWY', 'CTPFVPDDUYKBTAKH', 'CTPFVPDB593WABGP', 'CTPFVPHAGX8YA7RD', 'CTPFVPGPW8DU3XJF', 'CTPFVPGH5AGD8PZX', 'CTPFVPGMZ6GTZNZH', 'CTPFVPJ7HY68S45F', 'CTPFWYNJF8KMYKWG', 'CTPFVSU95M2RQUCM', 'CTPFVPKG8EMXFHMV', 'CTPFVSXF9FNZGKXP', 'CTPFVZTBFX56AB3T', 'CTPFVZT38N9RHZTA', 'ETHFYB46QHB6PMYG', 'ETHFYB47G8RMQ4GS', 'ETHFYB47ZTGRQ8CQ', 'ETHFYB47HW5MHKJP', 'ETHFYB47FDPG7MKY', 'ETHFYB47YX63WZZV', 'ETHFYB46E4NAKBBS', 'JCKFVJ54N4NZGPTP', 'TSHFKQFY82AZ8DH9', 'TSHFKQFYGBAYHSYH', 'TSHFKQFYUFJHZFH7', 'TSHFKQFYYVDMNGFH', 'TSHFYAVWTZY8SRGR', 'TSHFYAP9RPZ9UTRV', 'TSHFY8VHGJEWWNY9', 'TSHFJV3QF9FSHAVC', 'TSHFJV3QA8GU7VC4', 'TSHFJV3QBJCYQH3U', 'TSHFYCYWKSBNQFNQ', 'TSHFJV3Q99HSAQVG', 'TSHFJV3QKGEHGYDB', 'TSHFJV3QCWB63FNY', 'TSHFJV3QXJPTAYSC', 'TSHFJV3QRGUTJUFY', 'TSHFJV3Q95EN5Z54', 'TSHFJV3QS4K4A8ER', 'TSHFJV3QBGCS8Q7R', 'TSHFKQFYR6YYRUFN', 'TSHFKQY6CBKSRSEC', 'TSHFKQY6EJD6Z5FC', 'TSHFKQFY4BRGVKXG', 'TSHFJV3QF3THG9UH', 'TSHFKQY6AH45YYWH', 'TSHFJV3QKC9XA2KB', 'TSHFJV3QJ2EV7PWS', 'TSHFKPV2FZXSCJXH', 'TSHFJV3QM3EAWS6T', 'TSHFJV3Q4BJJ4G83', 'JEAEYNV6D4XAXZ5V', 'JEAEYNV6QZHJZFRH', 'JEAEYNV6WJVSK2JP', 'JEAEYNV7Y7SGZAJB', 'SHTF98P84QUYZNMC', 'TSHFFXYJG2BSKSV9', 'SHTF9HU8YXYJGKTH', 'SHTFFVYPMWHZ3SFQ', 'SHTF98P8MTY7ZXAZ', 'SHTF98P8F4ERZXAK', 'SHTF9MFKFJPN8DZA', 'SHTF8XG9YWFNC2ME', 'SHTF8XQRPAPP5YT8', 'SHTF98P8C6GXJHKR', 'SHTF8XMFJGEMKRBR', 'SHTF8XG9HBYHQSDD', 'TSHFHVPBYGMHPGBR', 'TSHFHVPBFGSGVXFM', 'TSHFHVPBYQP9SNBP', 'TSHFHVPB7F33EBNN', 'TSHFHVPBFZSXYHEP', 'TSHFHVPBMCXAZEQY', 'TSHFHVPBAUCHFQ3K', 'TSHFHVPBBUF2WHZY', 'TSHFHVPBHBFPU8SW', 'TSHFHVPBF4BJYW7N', 'TSHFHVPBXVFAYYW2', 'TSHFHVPBSDYRNG9N', 'TSHFHVPBVZ9HY9GG', 'TSHFHVPBB8K87ZMV', 'SHTF98P8JZZDZ3DQ', 'SHTFEGPHZGHPS4ZW', 'TSHFFYTQNA9CXMTZ', 'SHTFAG463RUFHFPR', 'TSHFFXYJRGVRYMHN', 'SHTF98P88Z6WHRQJ', 'SHTFEGPMZZWWQJ7A', 'SHTF98P8ASFYXWVV', 'SHTF8XQRJNACHGRM', 'TSHFG29MT7YYXDUQ', 'TSHFFXYJ2H4NJ8PF', 'SHTFFZPVYCQYYERJ', 'SHTFBG4PPAKGPEXE', 'SHTFBHFGEZV3VHKG', 'SHTFEGPMHZQC47HR', 'SHTFBG69XC92GMH7', 'SHTFEGPHYGPZSZBV', 'SHTFAG45TFHTPGGV', 'SHTFEGPHP2UVRYJY', 'SHTFEGPHBMQESMX6', 'SHTFEGPMGKDZBP8F', 'SHTFEGPMX8ZKHAMY', 'SHTFAG4BZGKKWGVX', 'SHTFENY2AZHBHGW5', 'SHTFEGPMQV6KB2HS', 'SHTFEGPM6HZ2W4YM', 'SHTFEGNZKGZY5FZZ', 'SHTFEGNQ7NSNA99D', 'SHTFAG46UGZMN5HH', 'SHTFEGPHFMGE6GKT', 'TSHFG2HTXEHZNGGZ', 'SHTFEGPMXNAJFC62', 'SHTFAHGFAZH6VGAD', 'SHTFEGPMAKYYFJYD', 'SHTFAHGF4YTDCN6T', 'TSHFG2HTQDXM3SQX', 'TSHFG2HTNYF2VG9Q', 'TSHFG2HTGWSVXBZB', 'TSHFG2HTMZDQEABX', 'TSHFG2HSGZMR6WCG', 'TSHFG2HTZFBZNH9X', 'TSHFG2HTCR8W5NZP', 'TSHFG2HTZBX7RMGZ', 'TSHFG2HT8YNZHWA5', 'TSHFG2HSNXP9KVD5', 'TSHFG2HTPGKEK3WX', 'TSHFG2HTGDKH9HH9', 'TSHFG2HTPXQAWZTS', 'SHTFEGPHHJBGSVHE', 'TSHFG29METVWDWZQ', 'SHTFAHFM36FRBED7', 'SHTFFV8VF99RZCW3', 'SHTFFVYP7K5F8D3C', 'SHTFFV8VHAH8N6Q9', 'SHTFFV8VC28EWZPQ', 'SHTFFV8VVXVBBUMH', ' ...
# track DF = 0.064 : ['TKPFCZ9EA7H5FYZH', 'TKPFCZ9EJZV2UVRZ', 'TKPFCZ9EHFCY5Z4Y', 'TKPFCZ9ESZZ7YWEF', 'TKPFCZ9EVXKBSUD7', 'TKPFCZ9EFK9DNWDA', 'TKPFDABN3GXYPFHE', 'TKPFCZ9ESGZYT8NH', 'TKPFCZ9DYU33FFXS', 'TKPFDABN4NQFVKZY', 'TKPFCZ9ENWGMX23W', 'TKPFZFSHHACG3FHC', 'TKPFZFSHQPDRGZTM', 'TKPFZ4YTRF3ZRTTH', 'TKPFZ4YTJZWBFYFZ', 'TKPFZFSH3F9ZA7C6', 'TKPFZ4YT7ZNYXG27', 'TKPFZ4YTGNZJDZDU', 'TKPFZ4YTX94CY9JX', 'TKPFCZ9EHCNAPKPU', 'TKPFDACEXAWUHGR7', 'TKPFCZ9ETR6YVXNG', 'TKPFD3K6K5TNYZGF', 'TKPFCZ9EGGYENTZS', 'TKPFD3K6ZMN79MPH', 'TKPFD3K6UZBYDZNY', 'TKPFD3K62JB9PEMR', 'TKPFCZ9EZDPZR5AH', 'TKPFWBGVGU9FCAYX', 'TKPFWBGPGVKVZARU', 'TKPFCZ9EVM2GZ4GF', 'TKPFWAG7YFWPMG5Y', 'TKPFCZ9E2UC3DR3F', 'TKPFCZ9ECDYYDNKA', 'TKPFGP48RBBKAGSZ', 'TKPFZYYR52RZQPHD', 'TKPFZF7YUEBNVYTM', 'TKPFZYYNUE65UKZQ', 'VESFKYJQ3H8PN4QM', 'BXRFGYQTPZNHEWFD', 'TSHFGYGH8Z6CQT4B', 'VESFGYJDGBAHTK8A', 'VESFGYJCB6BVH8G4', 'VESFKYJRGXBSGCQD', 'TSHFGYGHGZQZ85WU', 'TSHFKYKQ2UHZZAXF', 'BXRFGYQUTHXJKHHP', 'BXRFGGX685HKER8Y', 'TSHFGYGHHBF6AVWE', 'BXRFGZWRY43BCNAN', 'VESFGYJDQVNEA6DE', 'VESFGYJDB9DD5QME', 'VESFGYJDTX7WJBT7', 'VESFGYJCY74MT7YW', 'VESFGYJD6WYPCX6F', 'VESFGYJDBKHSE5H6', 'VESFGYJCNNHV7KNG', 'VESFGYJDKSQUKSFZ', 'VESFGYJDAGF4QZ3V', 'VESFGYJCZD3JUZRV', 'TSHFGG5SHU3GER2F', 'VESFGGWEHJ5GJXMX', 'VESFGJZGXKKQZGFJ', 'BXRFGYRYUXNNA2Z9', 'VESFGYJDQHGZS3SM', 'BXRFGYVBFFRQSY4Z', 'VESFGYJCX9TZN6ZC', 'BXRFGYQUZH5DCABH', 'VESFGYJCADUGKVGG', 'VESFGYJCDFVVHR4U', 'BXRFGYRYGUURZGDG', 'BXRFGYUGJCWWZ7UG', 'VESFGYJDJNXBANFG', 'VESFGYJCU2PM9HXR', 'VESFKYJPMPAC8M9S', 'VESFGYJCZH7GMD4E', 'VESFKYJQBYHWE5ZA', 'TSHFGYGHDVUZBNZA', 'VESFKYJREF5THSAN', 'VESFGGWEWQ47ZEZW', 'TSHFGYGHMVYZFWUG', 'VESFGYJCGXYEZYHT', 'VESFGYJCHH6UX6VF', 'TSHFGZWMYXXYWQPY', 'VESFKYJQAB5MERHY', 'TSHFGYGH2BQGF7YV', 'TSHFGG5UDNX5GWSM', 'VESFGYJCH27GQN9Z', 'VESFKYJQZ6SJHB35', 'TSHFGG5TSASGS3EV', 'VESFGYJCTBYDZWE2', 'TKPEYQ6YSFS8KEHK', 'TKPEYQ6YWVFUWRJH', 'TKPEYQ6YMX6GJEJG', 'TKPEYQ6Y3WBFYPZR', 'TKPEYQ6YZNMHSUQ9', 'TKPF3FPQGCHXHGRM', 'TKPF3FPMZ7FVMEH6', 'TKPF26ECK47PFGYC', 'TKPF26EQUZQG56TZ', 'TKPF3FPJNVVBKPRG', 'TKPF3FPKPQFXMWQK', 'TKPF3FPPTPDKPPFE', 'TKPF3FPZRD9GSNKR', 'TKPF3FPQJFH5KRK5', 'TKPF26EWFDBUXFGS', 'TKPF26ENSXEK6Y5D', 'TKPF3FPZRRJUWTAZ', 'TKPF3FPKHNWZ3UMG', 'TKPF3FPMC6PGGGYH', 'TKPF3FPNZ5XCHZ6R', 'TKPF3FPKTYM55SAV', 'TKPEYQ6YNHW8FV5R', 'TKPEYQ6YSFHCUHMA', 'TKPEYQ6YGFEAKDGF', 'TKPEYQ6YXZMGHGY2', 'TKPEYQ6YTHGUKUVG', 'TKPEYQ6YUZMGR3H6', 'TKPEYQ6YXGHRHSEW', 'TKPEYQ6YHKEYAXTY', 'TKPFWGHYHM8XYQMX', 'TKPFW6JMY9DQKSTY', 'TKPFUGG2J4GBNFZH', 'TKPFWGHYPNQYZNFW', 'TKPFWGHYBQQRJKUQ', 'TKPFU7EZK7UNYZFT', 'TKPFXS3CXVMW8PJQ', 'TKPFXZQ4EJ5G42FT', 'TKPFXH6YKP78ZJFY', 'TKPFZG64NDH5W4UY', 'TKPFZG5ZGSZZGR5F', 'TKPFZG7YWKYWSZ2P', 'TKPFZMQ8YMWNGXEU', 'TKPFZBZKR8HDZQJZ', 'TKPFZANS5H4CQTXA', 'TKPFZANU45HFMT8X', 'TKPFZCRTFWVNBG4U', 'SWSFVEV2BWZJDJ46', 'TKPFVEV38QCHVWTN', 'TKPFGZYSFREPAR8H', 'TKPFZ3JRKN7BF2EY', 'TKPFZ3JRWHEETCJP', 'TKPFVEV3KQNWYRZ4', 'TKPFGZYSCE255DSF', 'TKPFZ3JRSCCTXFMG', 'TKPFVEV4E4GHP9ZU', 'TKPFZ3JR3HQMHCWZ', 'TKPFZ3JRUBU8SZ2G', 'TKPFVEV3NFAUDF2Z', 'TKPFVEV3Q9DZHVKU', 'TKPFVEV3TGXWXAH3', 'SWSFVEV2BRQAYZCZ', 'TKPFZ3JR5CBF7WGW', 'TKPFZ3JRTTXYMHFN', 'TKPFVEV32U2KRVQ2', 'TKPFZ3JRDVRHWSFY', 'TKPFZ3JRXWS6PVZS', 'TKPFZ3JR9VTRKXHS', 'TKSFVEV4JDU4DDCZ', 'TKPFZ3JRCQDVCYD8', 'TKPFZ3JRSRHFYZA8', 'TKPFVEV4VXZ2FZC3', 'TKPFVEV4YZHYAZNN', 'TKPFZ3JRD83382S9', 'TKPFZ3JRGY3NABV3', 'TKPFZ3JRQGXUFH5H', 'TKPFZ3JRVBD2KXKK', 'TKPFZ3JRHN2ARFA5', 'TKPFZ3JR6HKJRZUY', 'SWSFVEV2GJVHBAQG', 'TKPFK3W6W8DZ2CGG', 'TKPFZ3JRVVZ5KHWQ', 'TKPFGZYS29B95HNU', 'TKPFZ3JRV4MFKWHY', 'TKPFZ3JRVMS6QYUS', 'TKPFVEV4NWHHG3TQ', 'TKPFGZYR8BZFNQZS', 'TKPFZ3JRTEUZSKAG', 'TKPFZ3JRA9E9ZVW8', 'TKPFZ3JRAYAJZJXF', 'TKPFVEV4XTGQ2WXZ', 'TKPFZ3JR5AHMQSXT', 'TKPFZ3JRWD9SKQF9', 'TKPFZ3JREAKFYXHR', 'TKPFK3W6VQFCYNTQ', 'TKPF7NWFB6MEDFD9', 'TKPFVEV3DMDBF5KY', 'TKPFGZYSTDVXATEE', 'TKPFZ3JRDGD9YM9E', 'TKPFZ3JRVU7BAAEX', 'TKPFVEV4C5ZY3K8U', 'TKPFZ3JRU7ZF9ZFG', 'TKPFZ3JRK9JMEYS5', 'TKPFZ3JRRNQGQPG7', 'TKPFVEV3S7S4DQ8U', 'TKTFJY5UCHHFYG6C', 'TKPFZ3JRDGHZ4VUW', 'TKPFK3W6U4UJ8KTP', 'TKPFZ3JRU3ASNZN7',  ...
# trackpant DF = 0.006 : ['TKPFCZ9EA7H5FYZH', 'TKPFCZ9EJZV2UVRZ', 'TKPFCZ9EHFCY5Z4Y', 'TKPFCZ9ESZZ7YWEF', 'TKPFCZ9EVXKBSUD7', 'TKPFCZ9EFK9DNWDA', 'TKPFDABN3GXYPFHE', 'TKPFCZ9ESGZYT8NH', 'TKPFCZ9DYU33FFXS', 'TKPFDABN4NQFVKZY', 'TKPFCZ9ENWGMX23W', 'TKPFCZ9EHCNAPKPU', 'TKPFDACEXAWUHGR7', 'TKPFCZ9ETR6YVXNG', 'TKPFD3K6K5TNYZGF', 'TKPFCZ9EGGYENTZS', 'TKPFD3K6ZMN79MPH', 'TKPFD3K6UZBYDZNY', 'TKPFD3K62JB9PEMR', 'TKPFCZ9EZDPZR5AH', 'TKPFCZ9EVM2GZ4GF', 'TKPFCZ9E2UC3DR3F', 'TKPFCZ9ECDYYDNKA', 'TKPFUGG2J4GBNFZH', 'TKPFPBCZARJAYW5G', 'TKPFZGQVKAQZZWAQ', 'TKPFNV3EVZGQYBNZ', 'TKPFNV3E5TYXUWYN', 'TKPFNV3ESGN9VM8D', 'TKPFZGQVBG7XGZTX', 'TKPFNV3GVUHG5U7E', 'TKPFNV3EBFWFBWCV', 'TKPFNV3ENZ6PBHXH', 'TKPFNV3FY7PYPHCZ', 'TKPFNV3EQFRYWSFT', 'TKPFYVRN3ZZZGAPH', 'TKPFYVRNGSKYPGT3', 'TKPFYVRN96GWWHZD', 'TKPFZ6WUKSB3H2S5', 'TKPFZ6WUVNRZZCGN', 'TKPFZ6WUGYFRMNSR', 'TKPFZ7EYFHX22A6G', 'TKPFZ7EYEHM9GAGH', 'TKPFZ7EYDUMGYBF5', 'TKPFZ3NWP2RYBXEA', 'TKPFYZEAFCHQWFPZ', 'TKPFZ3VYHZ6Q2HUZ', 'TKPFGFTFMFFU4CZA', 'TKPFGFTMRXWJJM4V', 'TKPFGFTMV2P2MEEM', 'TKPFGFTHHPZHRXDH', 'TKPFGFTHC79KQC6Z', 'TKPFGFTMGZU3ZFWJ', 'TKPFGFTMBZTFPF4D', 'TKPFGFTHZQ9GKMMQ', 'TKPFGFTHHB9NYC9Y', 'TKPFGFTJAXY6QNWZ', 'TKPFGFTFNY9TF3GN', 'TKPFGFTJSKEHM9GZ', 'TKPFW6455HJV2JVH', 'TKPFWW2ERYY5GQZN', 'TKPFWW2E2BSHUSHY', 'TKPFWW2E5QWD9HQT', 'TKPFYGUNNFVNFQF7', 'TKPFYGUNDKYGXZXF', 'TKPFYGUNG5DZEVB8', 'TKPEFVQB8Z65YCYQ', 'TKPF7BXYBH6UJAQD', 'TKPF7BXYDUHBQBYY', 'CRGFGQS63JKJZM34', 'TKPFGJTAYHH2CHZX', 'TKPF7BXYZMSFGH3Y', 'TKPF7BXYEDZAYEQQ', 'TKPF7BXY4PZGWXMT', 'TKPEFVQBA9FJA8WX', 'TKPEFVQAPRHKVJHJ', 'TROFGQSFMPC8HGZU', 'TKPFGQFTH4MVGAGR', 'TKPFHBS8JUTYEGGG', 'TKPF7BXYVYGXYHAD', 'TKPFGJTAJ9PDHKZ7', 'TKPF7BXYUFWF4JJT', 'TKPF7BXYCZGFHNG5', 'TKPFE7E8GZVEGMC6', 'TKPEJG8DEG5FA8VK', 'TKPF7BXYF5Q7U6HG', 'TKPFGJT9PT8MJSHN', 'TKPF7BXY5SUPBGTX', 'TKPFE7E8SHY75HG9', 'TKPFGJT8HXA4YVRP', 'CRGFGQRNCB7QVEME', 'TKPFZD4FZJFH6CRJ', 'TKPFC8J24Q8PBFDV', 'TKPFHEYEYB3VXTEC', 'TKPF7BXY9VHQBFH9', 'TKPFC8JYEVY5JWWJ', 'TKPFGKWFVAP3Y3HZ', 'TKPF7BXYDG3DXQ9F', 'TKPFGJT9JPKZKF6H', 'TKPFGJT8JFWNGKKK', 'TKPFC8JFED5W3QC4', 'TKPFGZAW5HNGHQQC', 'TKPFWJPGSYKJ2QK3', 'TKPFHBS8KUABZNZM', 'TKPFGJT9YYRDHM6M', 'TKPFUSC6HGRYR83H', 'TKPF7BXYWRKGAYGM', 'TKPF7BXYJYE6EYKJ', 'TROFGQSKNZNPTEGB', 'TKPFGJTAFNYRAAPJ', 'TKPFHDSWEMHSFRVW', 'TKPFGJT9XMDABUY4', 'TKPFWJPGKXUU3XP3', 'TKPFGJTAAT58GPA3', 'TKPFWJRVPUHWZY7S', 'TKPF7BXYYXUKBRYZ', 'TKPFHBS92PJUBJ63', 'TKPFWJPRHZK3UFCT', 'TKPFWJPR3JHK6PGZ', 'TKPFWJPRUFYEHEEE', 'TKPFWJPRYR3CAF2Z', 'TKPFGJTAZFG329S8', 'TROFGSZ4AHVZGPQH', 'TKPFGJTAVGYUWEZS', 'TKPFV4MTHHV7VXAY', 'TKPFGZAWU3Q2VAZA', 'TKPFW2SUFNCHQKXZ', 'TKPFW2SPBUY2FYE3', 'TKPFX8WJRUKHMCKX', 'TKPEQHGYQRXHCBFY', 'TKPFHNXFYCSVNZWM', 'TKPFHNXFMHUBCE9E', 'TKPFHNXKBZYFXGZK', 'TKPFHPFKMY7YSVJH', 'TKPFHPFKTZC4JGYP', 'TKPFHNXKSN6FGMHT', 'TKPFHNX3YWP4CSZG', 'TKPFHPFKVD69PVE4', 'TKPFHNXFRN5HYV65', 'TKPFHPFKYBBZMPYV', 'TKPFHPFKZ73M4R5N', 'TKPF7NWYBMP8GARX', 'TKPFZMVYJE9QHUW7', 'TKPFZMVFYHF7AH5Y', 'TKPFZMVY2ZVU3DME', 'TKPFZNYQ7ZZZFGTS', 'TKPFZMVF5B2GKFNT', 'TKPFZNYQFG95PNCZ', 'TKPFZMUZKHJ6PFCJ', 'TKPFZMUZBHC9BZR2', 'TKPFZMVYHVKZMGHQ', 'TKPFZMUZ9WWBHZDU', 'TKPFZMUZYNYG4ASH', 'TKPFZMVYMQJPC8GV', 'TKPFZMUZRZFGZMKK', 'TKPFHZH53TZHKGCQ', 'TKPFHZH7CYDMURHX', 'TKPFVMDHJK6VUYRW', 'TKPFVMDKFKNQRZGG', 'TKPFVMDE2RGGATZT', 'TKPFVMDKBZXARFGH', 'TKPFVMDK4GZBDGH3', 'TKPFVMDHR7FQZSEC', 'TKPFYG7THT4SKNEA', 'TKPFMTM8S3G3PCUY']
# comb DF = 0.013 : ['TKPFCZ9EA7H5FYZH', 'TKPFCZ9EJZV2UVRZ', 'TKPFCZ9EHFCY5Z4Y', 'TKPFCZ9ESZZ7YWEF', 'TKPFCZ9EVXKBSUD7', 'TKPFCZ9EFK9DNWDA', 'TKPFDABN3GXYPFHE', 'TKPFCZ9ESGZYT8NH', 'TKPFCZ9DYU33FFXS', 'TKPFDABN4NQFVKZY', 'TKPFCZ9ENWGMX23W', 'TKPFCZ9EHCNAPKPU', 'TKPFDACEXAWUHGR7', 'TKPFCZ9ETR6YVXNG', 'TKPFD3K6K5TNYZGF', 'TKPFCZ9EGGYENTZS', 'TKPFD3K6ZMN79MPH', 'TKPFD3K6UZBYDZNY', 'TKPFD3K62JB9PEMR', 'TKPFCZ9EZDPZR5AH', 'TKPFCZ9EVM2GZ4GF', 'TKPFCZ9E2UC3DR3F', 'TKPFCZ9ECDYYDNKA', 'SOCFVCCYUDEN2AVH', 'VESFHYSYHZ8HUDMY', 'VESFHYSZDTB2NGK3', 'VESFHJHPZUSZP2H2', 'VESFHJHQF7YJ3DHH', 'VESFHJHPHFHSSUJZ', 'VESFHRDANEBQFKWB', 'VESFHJHPGM4MJADF', 'VESFHYSZG7DYHGEY', 'VESFHJHPZJUBPS49', 'VESFHYSZRHUQGRRH', 'VESFHJHQREFDNKRQ', 'VESFHRDAQJ7PTFMM', 'VESFHRDBQWKBFHCZ', 'VESFHJHQ2VPZV4F7', 'VESFHYSWGNZWGGUK', 'VESFHJHPGC9CW6XA', 'VESFHYSXFN3GANGR', 'VESFHJHP4AYNWSAZ', 'VESFHJHPBCYZGZHE', 'VESFHJHPCZH2ACVK', 'DHYFHYT3QQU3UTNC', 'VESFHYSUYB7DBAZZ', 'VESFHRDCY32K427Y', 'VESFHJHQPTY2ZC8E', 'VESFHYSZCX3ZMWYZ', 'VESFHYSYCRHQYK9M', 'VESFHYSNVTMVDQSX', 'VESFZQYS3BFHNDZG', 'SOCF7WAP56FHXGVZ', 'SRTFYZFY7BXHR6BU', 'SRTFYZFYA7NFPYEM', 'SRTFYZFYDNWQWECU', 'SRTFYZFYTPRWCSST', 'BRFEZEF49JAWFCMD', 'BRFEZWU9FCHYPJDU', 'BRFEWB5RPBDW9DKP', 'BRFEX35MBHYTBYGC', 'KTAFD2U9ZM6FQ7D6', 'KTAFD2U9CPNYSPX7', 'KTAFD2U9KQXCQFZJ', 'KTAFD2U9H96RNW3H', 'KTAFD2U9YFW3CFPR', 'KTAFD2U9ZNKJGBGY', 'KTAFD2U96GQBXCSP', 'KTAFD2U9MWTSSDNU', 'KTAFD2U9YMZEMGGB', 'KTAFD2U9TD6VNWFY', 'VESFV6RKG9YK8HPW', 'TSHFYYSKNSS8PPZB', 'TSHFYYPRVYPAQSDU', 'TSHFYFYZ5HGYYA67', 'TSHFYF54UVAFWH4X', 'TSHFYYPRMZHFDAQG', 'TSHFYYPR8VF7GYN5', 'TSHFYYSKFTKPFNPQ', 'TSHFYYPRGFPHHHSD', 'TSHFYF4WHRDTXAPS', 'TSHFYFFY2NAWBQX6', 'TSHFYFYZSTDKBHZ8', 'TSHFY2FUYZATFCS2', 'TSHFYFXEAEQMCMKS', 'TSHFYF54P8XNTERY', 'TSHFXZNKTBGRH4ZU', 'TSHFXZNKFXZGVHGU', 'TSHFYF47M9CCZPGS', 'TSHFXYRD54YQFGKN', 'TSHFYF47DYSA8R5N', 'TSHFYFFYXKXHS9BX', 'TSHFYF4CQYHK5ZRH', 'TSHFYFVFNJFVHHTP', 'TSHFYYPRKXDZFTEZ', 'TSHFXYRDSE7EG5HW', 'TSHFXYRD5BGFZMV7', 'TSHFXYRD8GVJZEMH', 'TSHFXYRDHCTAGQU3', 'TSHFYFVFWFNFSNE3', 'TSHFY2FUUMWYK5B7', 'TSHFYFVFENQWGH7H', 'TSHFYFVJYQAETRXN', 'TSHFXYRD9KGJN3GA', 'TSHFYYSKAJCVFTKV', 'TSHFYYPRXAVHVJ7F', 'TSHFGFJFGFY9UNNS', 'TSHFYF4YCQRPY6VY', 'TSHFYF4WW2TT8ZGX', 'TSHFYF4YPH5YHWPB', 'TSHFGFJFTYMUZQ97', 'TSHFYF4ZXH6RSQPZ', 'TSHFYF4ZF7BXTKRV', 'TSHFYFXET9CUBNZA', 'TSHFYFYZNW2Q3NJJ', 'TSHFYFXETHVBHDED', 'TSHFYFYZCQHBMYJU', 'SOCFZ669PHYSYHEK', 'SOCFZF7HCFSSVT5X', 'TRKF7UQWBFX4ZN8W', 'TRKF7VGZZKDDXHMX', 'SOCFZ2MGHZZHBYGZ', 'TRKF7UQWNMUTGNCM', 'SOCFYVFYMBQ3K8MR', 'SOCFYTKHZEHXZRXE', 'SOCFZF5UF7ZYFJ2G', 'SOCFZF5JQGT3HKJN', 'SOCFZF3VNJFFT5EG', 'SOCFZF6UXKCAMTAQ', 'SOCFZF622HM7ZZMW', 'SOCFZF4U8HEAYYPF', 'SOCFZF53Z5GDNDY7', 'TRKF7UQXX3GKBAZT', 'TRKF7UQWQPFMFFHJ', 'SOCFZF6DQBN6UQNF', 'SOCFZF6ZGK5GE7XG', 'SOCFZF77KQBW9QFH', 'SOCFZF7MK5F9UXJQ', 'SOCFZ64VQZQYGNZG', 'SOCFZAH2ENHRC9SQ', 'SOCFZ64UGZPHYJ2X', 'SOCFZ66KW6R2ERJX', 'SOCFZ2MAPJHGZZEA', 'SOCFZ64VGH38UVEZ', 'TRKF7UQWGAFYKQFP', 'SOCFZ2N27NU6FV89', 'SOCFZ2NFMQHMJJHM', 'SOCFYVYVSFSRHYRC', 'SOCFZ2NFGU3GXUTG', 'SOCFZ2NFBTNEHBWV', 'SOCFZ2MSEGR267BZ', 'TRKF7UQW8Z2JEQS6', 'TRKF7UQVYGPNDDTA', 'TRKF7UQVKYDQYPKD', 'TRKF7UQVKHT2FVT6', 'TRKF7UQV6WMCC9UM', 'TRKF7UQW2NAMZYJY', 'TRKF7UQWZFJGGHNN', 'TRKF7UQVCSHAXYMZ', 'TRKF7UQWQZHJR53H', 'TRKF7UQVMYUGCTYB', 'TRKF7UQV7HHBXGAA', 'TRKF7UQW7Y9HBHBZ', 'TRKF7UQXFSXGWZZA', 'TRKF7UQWZBFMFFHU', 'SOCFNZKF2FF4964M', 'TKPFZ6WUKSB3H2S5', 'TKPFZ6WUVNRZZCGN', 'TKPFZ6WUGYFRMNSR', 'TKPFZ7EYFHX22A6G', 'TKPFZ7EYEHM9GAGH', 'TKPFZ7EYDUMGYBF5', 'TSHFBU9AE9ACCPHF', 'TSHFBU9K9DDG6PKQ', 'TSHFBU9BBZ5N3T9Y', 'VESFUS5GWMWAE5FF', 'VESFUQWHECZSQPPK', 'VESFUSCBKZRGBAKU', 'VESFUQW7UWKFC8NM', 'VESFUS64XSUYPYGV', 'VESFUS8FWCSY7MQJ', 'VESFV7TCYZMYRWEZ', 'VESFUQX7ZQHZFSAZ', 'TSHFWCPH58HTE4FT', 'TSHFWJZEBEGPHCTH', 'TSHFWJZEH8ERSCHN', 'TSHFWJZEZYHJFJQU', 'TSHFWJZEEUGVR2GC', 'TSHFWCPH49MZVNYM', 'TSHFWJZENAT4XRHJ', 'TSHFWCPH3K9Q9PGX', 'TSHFWJZEHUJGGUVV', 'TSHFWJZERKWXDF6R', 'TSHFWJZEVGQPDYZH', 'TSHFWJZEBYGWUK6P', 'TSHFWCPHZEAZXY9K', 'TSHFWCPHY7FJ4RHU', 'TSHFWJZEYSSJH2MC', 'TSHFWCPHXDAHAHZZ', ' ...
# yorker DF = 0.001 : ['TKPFCZ9EA7H5FYZH', 'TKPFCZ9EJZV2UVRZ', 'TKPFCZ9EHFCY5Z4Y', 'TKPFCZ9ESZZ7YWEF', 'TKPFCZ9EVXKBSUD7', 'TKPFCZ9EFK9DNWDA', 'TKPFDABN3GXYPFHE', 'TKPFCZ9ESGZYT8NH', 'TKPFCZ9DYU33FFXS', 'TKPFDABN4NQFVKZY', 'TKPFCZ9ENWGMX23W', 'TKPFCZ9EHCNAPKPU', 'TKPFDACEXAWUHGR7', 'TKPFCZ9ETR6YVXNG', 'TKPFD3K6K5TNYZGF', 'TKPFCZ9EGGYENTZS', 'TKPFD3K6ZMN79MPH', 'TKPFD3K6UZBYDZNY', 'TKPFD3K62JB9PEMR', 'TKPFCZ9EZDPZR5AH', 'TKPFCZ9EVM2GZ4GF', 'TKPFCZ9E2UC3DR3F', 'TKPFCZ9ECDYYDNKA']
# proudli DF = 0.012 : ['TKPFCZ9EA7H5FYZH', 'TKPFCZ9EJZV2UVRZ', 'TKPFCZ9EHFCY5Z4Y', 'TKPFCZ9ESZZ7YWEF', 'TKPFCZ9EVXKBSUD7', 'TKPFCZ9EFK9DNWDA', 'TKPFDABN3GXYPFHE', 'TKPFCZ9ESGZYT8NH', 'TKPFCZ9DYU33FFXS', 'TKPFDABN4NQFVKZY', 'TKPFCZ9ENWGMX23W', 'TKPFCZ9EHCNAPKPU', 'TKPFDACEXAWUHGR7', 'TKPFCZ9ETR6YVXNG', 'TKPFD3K6K5TNYZGF', 'TKPFCZ9EGGYENTZS', 'TKPFD3K6ZMN79MPH', 'TKPFD3K6UZBYDZNY', 'TKPFD3K62JB9PEMR', 'TKPFCZ9EZDPZR5AH', 'TKPFCZ9EVM2GZ4GF', 'TKPFCZ9E2UC3DR3F', 'TKPFCZ9ECDYYDNKA', 'SOCFYUYZKCB4BWTS', 'SOCFYV4MVKGW4QXK', 'TSHFYYSKNSS8PPZB', 'TSHFYYPRVYPAQSDU', 'TSHFYFYZ5HGYYA67', 'TSHFYF54UVAFWH4X', 'TSHFYYPRMZHFDAQG', 'TSHFYYPR8VF7GYN5', 'TSHFYYSKFTKPFNPQ', 'TSHFYYPRGFPHHHSD', 'TSHFYF4WHRDTXAPS', 'TSHFYFFY2NAWBQX6', 'TSHFYFYZSTDKBHZ8', 'TSHFY2FUYZATFCS2', 'TSHFYFXEAEQMCMKS', 'TSHFYF54P8XNTERY', 'TSHFXZNKTBGRH4ZU', 'TSHFXZNKFXZGVHGU', 'TSHFYF47M9CCZPGS', 'TSHFXYRD54YQFGKN', 'TSHFYF47DYSA8R5N', 'TSHFYFFYXKXHS9BX', 'TSHFYF4CQYHK5ZRH', 'TSHFYYPRKXDZFTEZ', 'TSHFXYRDSE7EG5HW', 'TSHFXYRD5BGFZMV7', 'TSHFXYRD8GVJZEMH', 'TSHFXYRDHCTAGQU3', 'TSHFY2FUUMWYK5B7', 'TSHFXYRD9KGJN3GA', 'TSHFYYSKAJCVFTKV', 'TSHFYYPRXAVHVJ7F', 'TSHFGFJFGFY9UNNS', 'TSHFYF4YCQRPY6VY', 'TSHFYF4WW2TT8ZGX', 'TSHFYF4YPH5YHWPB', 'TSHFGFJFTYMUZQ97', 'TSHFYF4ZXH6RSQPZ', 'TSHFYF4ZF7BXTKRV', 'TSHFYFXET9CUBNZA', 'TSHFYFYZNW2Q3NJJ', 'TSHFYFXETHVBHDED', 'TSHFYFYZCQHBMYJU', 'SWSFFUFZW8ZH5UAJ', 'SWSFFUFZMAHCJ5KG', 'SWSFFVKBHZVGESZR', 'SWSFFVKBAZGKCQCX', 'SWSFFVKBCQG5FHPF', 'SWSFFVK89VKGHBZN', 'SWSFFUFZ6PVYHSGG', 'SWSFFVK8NZ6ZHDZB', 'SWSFFVKBH5YEGFFN', 'SWSFFVK8RYHBBFAH', 'SWSFFVKBB8FHEB7R', 'SWSFFVKBCY7RSGYJ', 'SWSFFVKBQUWH72KH', 'SWSFFVKBYG9ZUBTW', 'SWSFFVKB9WRATGPJ', 'SWSFFVKBF5U5AHBR', 'SWSFFVKBZZTJXBYZ', 'TSHFZ5BF8FDR9HQC', 'TSHFNETNSSBQ52PG', 'TSHFNHEFTKZYMWCP', 'TSHFNFF2DMQ47PEA', 'TSHFNHHMVFVVZDXQ', 'SWSFMJGT3MWCDDM7', 'TSHFNHHK7MWQDEVY', 'TSHFMZFDTM6UYNMS', 'TSHFNETNKMHK73FU', 'TSHFNXNJZDXDXHP2', 'TSHFNETMT2VSKNZP', 'TKPFNWG6WSDEXBAH', 'TSHFZJY5NTK7YMAA', 'SWSFMJZHZFUCHHTH', 'TSHFNETNYE5GFSRB', 'TSHFZRGJFFJPN5PJ', 'SWSFHXFGNTY3RSGZ', 'TSHFMZFDQYARZSEG', 'TSHFNUGQH7ZRJVTZ', 'TSHFM2XZRZGDUFBW', 'TSHFNUGRDWZJDAH2', 'TSHFNHEEDAJS3DE3', 'TSHFNUHGETNJYMAY', 'TSHFNUGUB3UTXPFE', 'TSHFNETNDS9Z3N7E', 'TSHFZHMEESX4QBYG', 'TSHFNQW3HJWFZBER', 'RUGFNHZTYJGPNFW8', 'TSHFNQW3HVZ4G2KC', 'TSHFMZFDDQWQ3UQG', 'TSHFM6DYMHWSDEBE', 'TSHFMZFD3RSMGGG8', 'TSHFNHEFP5ZJZWVV', 'TSHFNUH73AFGTDZ2', 'TSHFNQW3CSZTGXGU', 'TSHFNHEFYDGA85ZU', 'TSHFNUHDYVE2WGGM', 'SWSFMF3AUHYGMGYF', 'TSHFMZFDKA9RUG4P', 'TSHFZYA7YGZP3ZKH', 'TSHFNUENXZHPJKAT', 'TSHFMZFDGARJ9JZE', 'TSHFMJKZZMDACKTN', 'TSHFMZFDDQQEYUZF', 'TSHFZHHWFCBNBFH6', 'TSHFNQW3Y5ZADXHN', 'TSHFMZFD4RNGN4YS', 'SWSFMF3ADDNRDJT5', 'SWSFMKGBF7FWZ3Q4', 'TSHFNQW3G6BPXYHP', 'TSHFMZFDJDHNHXGM', 'TSHFNHEFYUXXZ3SU', 'TSHFZHMTFXZ83HPY', 'TSHFNUGRAZ6YXHMS', 'TSHFNFF2KBFGU2SY', 'SWTFMSQFVZXYCXNY', 'TSHFNQW3Y7AKFHC2', 'TSHFMZFDGM4ANGYQ', 'TSHFNQW3GVJFK97G', 'TSHFNHEFRGHAB6DB', 'TSHFNFF2ZXUPGBXT', 'TSHFZ5BFKYTRE6YP', 'TSHFNQW34KMHZ3YN', 'TSHFZHHWS2EWXG7D', 'TSHFZHHWVYEYV4AD', 'TSHFNFF2V72JRHYA', 'TSHFNFF246KHRUKG', 'SWSFMJGS8HVBPEH6', 'TSHFNETNCFRE57ZF', 'SWSFMYP6NHAT5QNK', 'TSHFNFF2N8ZVFGHF', 'TSHFZHHWXD7FZYHU', 'TKPFNWG7ZDTTPSS5', 'TSHFTHXAZQ3HHCFH', 'TSHFNUGY3EU3Z4GQ', 'TSHFJMYGGYWXGXWU', 'TSHFZHHWHR33F55E', 'SWSFMJGTCUB3ZMVQ', 'TSHFNUGTMGESSUZK', 'SWSFMTNHE2PCYWFZ', 'TSHFNHEFZ95HTCAB', 'TSHFNETNAKJS8YH7', 'TSHFZ5BFZFXR8XJE', 'TSHFNHEFHZYYGNEV', 'TSHFNETNEHFMVRFP', 'TSHFNHEGMQEDQEHZ', 'TSHFNHEFCC8E99UF', 'TSHFZHHW6QGMR3GM', 'TSHFNHEFZHUCWGH6', 'SWSFMTNHBCFHDHQN', 'TSHFNQW35ESNJGQH', 'TSHFNQW3TQWPYCHK', 'TSHFNYTT6PEMGRJA', 'TSHFNHEF9UFCXAMG', 'TSHFNHEFAJGUMSWK', 'TSHFM2XPFUYCGSMB', 'TSHFNUHMNR8ETUEP', 'TSHFNQW3XQFPZGGA', 'TKPFNWG6AHUJPFXJ', 'TSHFNUHHUNJYBFDA', 'TSHFM6GHAV9WC3YN', 'TSHFZHHWQAHYFSWF', 'SWSFMYPMNTF3KBAP', 'TSHFM6EANEWFN4RE', 'SWSFHZP7A87ZUEA3', 'SWSFMJGTQFMZGZQH', 'TSHFNUHMUMHBRTP7', 'TSHFM2XA9XRGM5GY', 'TSHFNHEEXKAG4HXY', 'TSHFNHEGNSYRAPDX', 'TSHFNHEFRHSFPJVZ', 'TSHFNHEFTSZDY5GA', 'TSHFNQW3WWCMMXYZ', 'TSHFPNR322XKKCKW', 'TSHFNQW3HGC9GXJU', 'TSHFNHEFH6P4PZFM' ...
# cotton DF = 0.293 : ['TKPFCZ9EA7H5FYZH', 'TKPFCZ9EJZV2UVRZ', 'TKPFCZ9EHFCY5Z4Y', 'TKPFCZ9ESZZ7YWEF', 'TKPFCZ9EVXKBSUD7', 'TKPFCZ9EFK9DNWDA', 'TKPFDABN3GXYPFHE', 'TKPFCZ9ESGZYT8NH', 'TKPFCZ9DYU33FFXS', 'TKPFDABN4NQFVKZY', 'TKPFCZ9ENWGMX23W', 'TKPFCZ9EHCNAPKPU', 'TKPFDACEXAWUHGR7', 'TKPFCZ9ETR6YVXNG', 'TKPFD3K6K5TNYZGF', 'TKPFCZ9EGGYENTZS', 'TKPFD3K6ZMN79MPH', 'TKPFD3K6UZBYDZNY', 'TKPFD3K62JB9PEMR', 'TKPFCZ9EZDPZR5AH', 'TKPFCZ9EVM2GZ4GF', 'TKPFCZ9E2UC3DR3F', 'TKPFCZ9ECDYYDNKA', 'SOCFVCCYUDEN2AVH', 'SHTFVVEHGJJTM4QN', 'TSHFYC82QKRSV6ZA', 'SHTFVVEHJKNZ7VNR', 'TSHFYC82QNATNDPD', 'SHTFVVEHWHRGQMKY', 'SHTFVVEHFY5F4QVH', 'SHTFVVEHGB3M4JVU', 'SHTFVVCNTBZUFGXR', 'SHTFVVCNDWPWPQDE', 'SHTFVVCNJNSZGNZ3', 'SHTFVVEHYYFGGKM6', 'SHTFVVCNCVHW9ARP', 'SHTFVVCNJSMCTAH2', 'SHTFVVEHZEZRDEJJ', 'SHTFVVEH8KY6F5BX', 'SHTFVVEHMCY2GYFC', 'SHTFVVEHGDUN99HD', 'SHTFVVEHZUETFQAM', 'SHTFVVCNXF5GYTHK', 'SHTFVVCNH3ECDGVF', 'TSHFZF6KZTHBEFC6', 'TSHFZF6KXUEAS5WS', 'TSHFZF6KF2GKH5ZM', 'TSHFZF6KFHSFFGCC', 'TSHFZF6KB2BAVGBU', 'TSHFZF6KGHFQWYXW', 'TSHFZF6K22MNCSHE', 'SOCFBBTZBDD73DHH', 'SOCFBKYNQ7DMX6ZM', 'SOCFJZBZSUG2CWSY', 'SOCFAEKEPDWZYGEG', 'SOCFAEKFTC9QVR7Y', 'SOCFAGQYHQ94WQPY', 'SOCFAJY9ZKQQEU6Y', 'SOCFJZBZGQBHZZC8', 'SOCFFMT7U5VXXCUV', 'SOCFMFJFMKNPW3CG', 'SOCFJZBZGKHYBHZC', 'SOCFMFJFANEFCHF8', 'SOCFMFJFGM9CAMZR', 'VESFHYSYHZ8HUDMY', 'VESFHYSZDTB2NGK3', 'VESFHJHPZUSZP2H2', 'VESFKYJQ3H8PN4QM', 'VESFHJHQF7YJ3DHH', 'BXRFGYQTPZNHEWFD', 'VESFGYJDGBAHTK8A', 'VESFGYJCB6BVH8G4', 'VESFKYJRGXBSGCQD', 'VESFZAMXSDYEC5JB', 'VESFHJHPHFHSSUJZ', 'BXRFH3SGHKWHQCQA', 'BXRFGYQUTHXJKHHP', 'BXRFGGX685HKER8Y', 'TSHFHJKSY8FNR7PV', 'BXRFGZWRY43BCNAN', 'VESFHRDANEBQFKWB', 'VESFHJHPGM4MJADF', 'VESFGYJDQVNEA6DE', 'VESFGYJDB9DD5QME', 'TSHFHJKRPYSHNEMG', 'VESFGYJDTX7WJBT7', 'VESFGYJCY74MT7YW', 'TSHFHJKRU3HPDFEJ', 'VESFHYSZG7DYHGEY', 'VESFHJHPZJUBPS49', 'VESFGYJD6WYPCX6F', 'VESFGYJDBKHSE5H6', 'VESFZAGYDM5FZYTD', 'VESFHYSZRHUQGRRH', 'VESFGYJCNNHV7KNG', 'TSHFHJKR4AF3G9KY', 'VESFZAHUGUDX6KG8', 'VESFGYJDKSQUKSFZ', 'VESFGYJDAGF4QZ3V', 'TSHFHJKR4XEERYWR', 'VESFHJHQREFDNKRQ', 'VESFGYJCZD3JUZRV', 'VESFZAM6DPFT2VHZ', 'VESFZANYWFQFYXZ2', 'VESFGGWEHJ5GJXMX', 'TSHFHJKR4CAKQVC5', 'TSHFHJKRCHG8R7YS', 'VESFGJZGXKKQZGFJ', 'VESFZAMDXEGZCGSK', 'BXRFH3SG2DGHPNT5', 'BXRFGYRYUXNNA2Z9', 'VESFHRDAQJ7PTFMM', 'VESFGYJDQHGZS3SM', 'VESFHRDBQWKBFHCZ', 'VESFZAHF3QEQAR4E', 'VESFHJHQ2VPZV4F7', 'BXRFGYVBFFRQSY4Z', 'VESFZAKZ2ADEZEHM', 'VESFHYSWGNZWGGUK', 'VESFGYJCX9TZN6ZC', 'BXRFGYQUZH5DCABH', 'VESFGYJCADUGKVGG', 'VESFGYJCDFVVHR4U', 'VESFZAJGQJ5JYRZY', 'VESFHJHPGC9CW6XA', 'TSHFZ5UVAKHJ5GGY', 'VESFZAZWJBRBHMAB', 'TSHFHJKRJBUK2TFG', 'SRTFHZ5V5CFUZQM5', 'VESFHYSXFN3GANGR', 'BXRFGYRYGUURZGDG', 'VESFZ95QDTSNJZYG', 'VESFHJHP4AYNWSAZ', 'BXRFGYUGJCWWZ7UG', 'VESFZ95Q4FHSKHGF', 'VESFZAPZF9GYJ27Z', 'TSHFHJKRKB8MMAZY', 'VESFGYJDJNXBANFG', 'VESFGYJCU2PM9HXR', 'VESFHJHPBCYZGZHE', 'VESFKYJPMPAC8M9S', 'VESFHJHPCZH2ACVK', 'BXRFHFVSCNRFFTMG', 'VESFGYJCZH7GMD4E', 'VESFGYJDWUH364V2', 'VESFKYJQBYHWE5ZA', 'DHYFHYT3QQU3UTNC', 'VESFHYSUYB7DBAZZ', 'VESFKYJREF5THSAN', 'TSHFHJKSFKTFUR2B', 'VESFGGWEWQ47ZEZW', 'TSHFHJKSVR5D3HHG', 'VESFGYJDFBUZG6FQ', 'VESFGYJCGXYEZYHT', 'TSHFHJKRVZZTKTD4', 'VESFGYJCHH6UX6VF', 'TSHFZ5UVTYC3T7NB', 'TSHFHJKRAVBBXFWF', 'TSHFHJKS88WDXB7Z', 'VESFHRDCY32K427Y', 'VESFZAGW4AG8WJUF', 'VESFHJHQPTY2ZC8E', 'TSHFHJKRYFDCBGJC', 'TSHFZ5UVWY9CJ9JM', 'VESFKYJQAB5MERHY', 'VESFHYSZCX3ZMWYZ', 'TSHFHJKR46TAQNG6', 'VESFHYSYCRHQYK9M', 'VESFHYSNVTMVDQSX', 'VESFGYJCH27GQN9Z', 'VESFKYJQZ6SJHB35', 'VESFGYJCTBYDZWE2', 'TROFZQZBPSE4ZBWN', 'TROFYFX6XK4HYZFN', 'TROFYKY4A5KGVJHB', 'TROFZQZB5YVN5GNW', 'TROFYJY6SHFAGWVU', 'TROFZQZBZAPDHHYQ', 'TROFYJQZMZZHTYHK', 'TROFZQZBZTMBGX7R', 'TROFZQZBMVN6HQKX', 'TROFZQZBGD5JHDJZ', 'TROFZQZBFQXANKSM', 'SHTFYPH5ZY8FHQN7', 'TROFY2YDSF86AUSB', 'TROFYFX6ZF5DUKGH', 'TROFYFX6ADFBGJKQ', 'TROFYJR4GB95FYYH', 'TROFY2YFSMNNGQXJ', 'TROFY2YF45HJWGCN', 'BXRF5MQHZ4NUY2ZH', 'TSHFVJU3XHYFR2SZ', 'BXRF5MQGGRSNSN5Q', 'BXRF5MQG9YRDM5AM', 'BXRF5MQH76K6ZS99', 'BXRF5MQHSYQPWUYZ', 'TSHF3KH4PCPGWERR', 'BXRF5MQHZXFQXYVQ', 'TSHEYRU4TZ7ZXWHZ', ...
# 100 DF = 0.106 : ['TKPFCZ9EA7H5FYZH', 'TKPFCZ9EJZV2UVRZ', 'TKPFCZ9EHFCY5Z4Y', 'TKPFCZ9ESZZ7YWEF', 'TKPFCZ9EVXKBSUD7', 'TKPFCZ9EFK9DNWDA', 'TKPFDABN3GXYPFHE', 'TKPFCZ9ESGZYT8NH', 'TKPFCZ9DYU33FFXS', 'TKPFDABN4NQFVKZY', 'TKPFCZ9ENWGMX23W', 'TKPFCZ9EHCNAPKPU', 'TKPFDACEXAWUHGR7', 'TKPFCZ9ETR6YVXNG', 'TKPFD3K6K5TNYZGF', 'TKPFCZ9EGGYENTZS', 'TKPFD3K6ZMN79MPH', 'TKPFD3K6UZBYDZNY', 'TKPFD3K62JB9PEMR', 'TKPFCZ9EZDPZR5AH', 'TKPFCZ9EVM2GZ4GF', 'TKPFCZ9E2UC3DR3F', 'TKPFCZ9ECDYYDNKA', 'VESFHYSYHZ8HUDMY', 'VESFHYSZDTB2NGK3', 'VESFHJHPZUSZP2H2', 'VESFKYJQ3H8PN4QM', 'VESFHJHQF7YJ3DHH', 'BXRFGYQTPZNHEWFD', 'VESFGYJDGBAHTK8A', 'VESFGYJCB6BVH8G4', 'VESFKYJRGXBSGCQD', 'VESFHJHPHFHSSUJZ', 'BXRFH3SGHKWHQCQA', 'BXRFGYQUTHXJKHHP', 'BXRFGGX685HKER8Y', 'TSHFHJKSY8FNR7PV', 'BXRFGZWRY43BCNAN', 'VESFHRDANEBQFKWB', 'VESFHJHPGM4MJADF', 'VESFGYJDQVNEA6DE', 'VESFGYJDB9DD5QME', 'TSHFHJKRPYSHNEMG', 'VESFGYJDTX7WJBT7', 'VESFGYJCY74MT7YW', 'TSHFHJKRU3HPDFEJ', 'VESFHYSZG7DYHGEY', 'VESFHJHPZJUBPS49', 'VESFGYJD6WYPCX6F', 'VESFGYJDBKHSE5H6', 'VESFHYSZRHUQGRRH', 'VESFGYJCNNHV7KNG', 'TSHFHJKR4AF3G9KY', 'VESFGYJDKSQUKSFZ', 'VESFGYJDAGF4QZ3V', 'TSHFHJKR4XEERYWR', 'VESFHJHQREFDNKRQ', 'VESFGYJCZD3JUZRV', 'VESFGGWEHJ5GJXMX', 'TSHFHJKR4CAKQVC5', 'TSHFHJKRCHG8R7YS', 'VESFGJZGXKKQZGFJ', 'BXRFH3SG2DGHPNT5', 'BXRFGYRYUXNNA2Z9', 'VESFHRDAQJ7PTFMM', 'VESFGYJDQHGZS3SM', 'VESFHRDBQWKBFHCZ', 'VESFHJHQ2VPZV4F7', 'BXRFGYVBFFRQSY4Z', 'VESFHYSWGNZWGGUK', 'VESFGYJCX9TZN6ZC', 'BXRFGYQUZH5DCABH', 'VESFGYJCADUGKVGG', 'VESFGYJCDFVVHR4U', 'VESFHJHPGC9CW6XA', 'TSHFHJKRJBUK2TFG', 'SRTFHZ5V5CFUZQM5', 'VESFHYSXFN3GANGR', 'BXRFGYRYGUURZGDG', 'VESFHJHP4AYNWSAZ', 'BXRFGYUGJCWWZ7UG', 'TSHFHJKRKB8MMAZY', 'VESFGYJDJNXBANFG', 'VESFGYJCU2PM9HXR', 'VESFHJHPBCYZGZHE', 'VESFKYJPMPAC8M9S', 'VESFHJHPCZH2ACVK', 'BXRFHFVSCNRFFTMG', 'VESFGYJCZH7GMD4E', 'VESFGYJDWUH364V2', 'VESFKYJQBYHWE5ZA', 'DHYFHYT3QQU3UTNC', 'VESFHYSUYB7DBAZZ', 'VESFKYJREF5THSAN', 'TSHFHJKSFKTFUR2B', 'VESFGGWEWQ47ZEZW', 'TSHFHJKSVR5D3HHG', 'VESFGYJDFBUZG6FQ', 'VESFGYJCGXYEZYHT', 'TSHFHJKRVZZTKTD4', 'VESFGYJCHH6UX6VF', 'TSHFHJKRAVBBXFWF', 'TSHFHJKS88WDXB7Z', 'VESFHRDCY32K427Y', 'VESFHJHQPTY2ZC8E', 'TSHFHJKRYFDCBGJC', 'VESFKYJQAB5MERHY', 'VESFHYSZCX3ZMWYZ', 'TSHFHJKR46TAQNG6', 'VESFHYSYCRHQYK9M', 'VESFHYSNVTMVDQSX', 'VESFGYJCH27GQN9Z', 'VESFKYJQZ6SJHB35', 'VESFGYJCTBYDZWE2', 'TROFZQZBPSE4ZBWN', 'TROFZQZB5YVN5GNW', 'TROFZQZBZAPDHHYQ', 'TROFZQZBZTMBGX7R', 'TROFZQZBMVN6HQKX', 'TROFZQZBGD5JHDJZ', 'TROFZQZBFQXANKSM', 'SHTFYPH5ZY8FHQN7', 'TSHF2KH2G4XAQAF7', 'TSHF2KWHG2P4GZUU', 'TKPFUGG2J4GBNFZH', 'SHTFA82ZG5GJBHMX', 'SHTFA82Z7DYRZVRD', 'SHTFA82ZK95WV8DK', 'SHTFA82Z9JAZRZXU', 'SHTF5RCSSJWXP7TR', 'SHTFA82ZRSGX7KR5', 'SHTF4FDXJCXDYFGH', 'SHTF79GAYSZ8F9S6', 'SHTFMY2XUV3DSZVW', 'SHTFYGBANZEDPSUU', 'SHTF4ZCCRZZRUJDF', 'SHTF4FDXZP2KDQKA', 'SHTF5RCSEDKQGGWG', 'SHTF4FDX4GHEBWJ6', 'SHTF4FDXFWNEVHGC', 'SHTF4FDXFFUB7XMN', 'SHTFMY2XKBNZFZPZ', 'SHTF4ZCCBTQT4VFA', 'SHTF4NAXYUN8ZT5B', 'SHTEYFZVZQ9ZC3MQ', 'SHTF4FDXVNMQHUQM', 'SHTF4ZCCGTDSQCVK', 'SHTF4ZCCMGQH8DUQ', 'SHTF4ZCCG2EGZDVZ', 'SHTF4ZCCFU7V66BS', 'SHTFA82ZZSANMWK9', 'SHTFN2EPBYAMUFHM', 'TSHF6RWFHSCZFJFC', 'TSHF6H6KX4VRWEGU', 'TSHF6H6KMJBMHDJX', 'TSHFPYDTG7ERZUSS', 'TSHFUSFDAS3AGBPF', 'TSHF5FFXPGVDYYRH', 'TSHF4Y42YPT2GXPZ', 'TSHFUTHFFN8VMHNW', 'TSHFUTG5JZGFTXDF', 'TSHFUSFDCVNNHAJP', 'TSHFUSFDDU8HMWXM', 'TSHF2NZWZRFHSYCZ', 'TSHF2NZWBB5GGACT', 'TSHFUSFD5FBWR8NW', 'TSHF34PEGC9AENZH', 'TSHF6TYMGYT2G7HJ', 'TSHFUSFDSBBBG6ZF', 'TSHF2KRV5R3YXC75', 'TSHFFU55GBSDETGJ', 'TSHF2GDG5SXDJG7Q', 'TSHF2GDGBBDHJSHA', 'TSHF3A67WUAH8NGC', 'TSHF2KRVKSYWA8G7', 'TSHF2KRVTFFEHY2G', 'TSHFUSFD7QH82VVK', 'TSHF2GDGEPU4NEZH', 'TSHF34PEXH5AVGRR', 'TSHFUSFDAZRJCUVM', 'TSHF2NZWFGECB6GH', 'TSHF34PEWJWG5ZTN', 'TSHEY5TTKCJ4YCP6', 'TSHFUSFDYXEGGGD7', 'TSHF4Y42QXGAUGZA', 'TSHFUSFDXBGYJ22Z', 'SHTFHXGZJZTGHWFY', 'SHTFHFHHXDQNWYUR', 'SHTFT26GG9TYR49Z', 'DHYFHFU6UCJHMZBY', 'VESFZQYS3BFHNDZG', 'TSHFVEV3VUNJNSGH', 'TSHFVEV3ANACBVGE', 'TSHFVEV34XPEDFJH', 'TSHFVEV3GM5Y93ZT', 'TSHFVEV2HUWWBFFR', 'TSHFVEV35ES5DYCY', 'TSHFVEV3Z8RJYY3K', 'TSHFVEV2XDJTSCNZ', 'T ...
# fabric DF = 0.173 : ['TKPFCZ9EA7H5FYZH', 'TKPFCZ9EJZV2UVRZ', 'TKPFCZ9EHFCY5Z4Y', 'TKPFCZ9ESZZ7YWEF', 'TKPFCZ9EVXKBSUD7', 'TKPFCZ9EFK9DNWDA', 'TKPFDABN3GXYPFHE', 'TKPFCZ9ESGZYT8NH', 'TKPFCZ9DYU33FFXS', 'TKPFDABN4NQFVKZY', 'TKPFCZ9ENWGMX23W', 'TKPFCZ9EHCNAPKPU', 'TKPFDACEXAWUHGR7', 'TKPFCZ9ETR6YVXNG', 'TKPFD3K6K5TNYZGF', 'TKPFCZ9EGGYENTZS', 'TKPFD3K6ZMN79MPH', 'TKPFD3K6UZBYDZNY', 'TKPFD3K62JB9PEMR', 'TKPFCZ9EZDPZR5AH', 'TKPFCZ9EVM2GZ4GF', 'TKPFCZ9E2UC3DR3F', 'TKPFCZ9ECDYYDNKA', 'SHTFVVEHGJJTM4QN', 'SHTFVVEHJKNZ7VNR', 'SHTFVVEHWHRGQMKY', 'SHTFVVEHFY5F4QVH', 'SHTFVVEHGB3M4JVU', 'SHTFVVCNTBZUFGXR', 'SHTFVVCNDWPWPQDE', 'SHTFVVCNJNSZGNZ3', 'SHTFVVEHYYFGGKM6', 'SHTFVVCNCVHW9ARP', 'SHTFVVCNJSMCTAH2', 'SHTFVVEHZEZRDEJJ', 'SHTFVVEH8KY6F5BX', 'SHTFVVEHMCY2GYFC', 'SHTFVVEHGDUN99HD', 'SHTFVVEHZUETFQAM', 'SHTFVVCNXF5GYTHK', 'SHTFVVCNH3ECDGVF', 'BXRFGYQTPZNHEWFD', 'BXRFGYQUTHXJKHHP', 'BXRFGGX685HKER8Y', 'TSHFHJKSY8FNR7PV', 'BXRFGZWRY43BCNAN', 'TSHFHJKRPYSHNEMG', 'TSHFHJKRU3HPDFEJ', 'TSHFHJKR4AF3G9KY', 'TSHFHJKR4XEERYWR', 'TSHFHJKR4CAKQVC5', 'TSHFHJKRCHG8R7YS', 'BXRFGYRYUXNNA2Z9', 'BXRFGYVBFFRQSY4Z', 'BXRFGYQUZH5DCABH', 'TSHFHJKRJBUK2TFG', 'BXRFGYRYGUURZGDG', 'BXRFGYUGJCWWZ7UG', 'TSHFHJKRKB8MMAZY', 'TSHFHJKSFKTFUR2B', 'TSHFHJKSVR5D3HHG', 'TSHFHJKRVZZTKTD4', 'TSHFHJKRAVBBXFWF', 'TSHFHJKS88WDXB7Z', 'TSHFZYYMGNZDR2ZH', 'TSHFHJKRYFDCBGJC', 'TSHFHJKR46TAQNG6', 'TSHFZYYHZTUA8ZQM', 'TSHFZ8TSYS3FD6AN', 'TSHFZYYHYJKPFR7P', 'TSHFZYYHTSTSYZNG', 'TROFZQZBPSE4ZBWN', 'TROFYKY4A5KGVJHB', 'TROFZQZB5YVN5GNW', 'TROFYJY6SHFAGWVU', 'TROFZQZBZAPDHHYQ', 'TROFZQZBZTMBGX7R', 'TROFZQZBMVN6HQKX', 'TROFZQZBGD5JHDJZ', 'TROFZQZBFQXANKSM', 'SHTFYPH5ZY8FHQN7', 'TSHFVJU3XHYFR2SZ', 'TSHEYQ73DFUY8QTQ', 'TSHF3KH4PCPGWERR', 'TSHEYRU4TZ7ZXWHZ', 'TSHEYQ73VXZGAJY3', 'TSHEXH59HGMM2X8P', 'TSHEYR7EJDTPTBDW', 'TSHEXH594YXPYNEQ', 'TSHEXH5986S35HJP', 'TSHEXH59UKJ7SUPR', 'TSHEXH594ZTCQ6AZ', 'TSHEXH59AAMVZKM8', 'TSHEXH59JKHGZYTM', 'TSHEXH59ZKPE8FDK', 'TSHEXM9HRJ3JGCZX', 'TSHEYR7EX5BA5HQA', 'TSHEXH5ARCB7ZPMY', 'TSHEXH59GFFRRGFH', 'TSHEXH59FAXKYQUN', 'TSHEXH59YBYWWDSY', 'TSHEYQ73EG9R29U4', 'TSHEXH5BPRGZFYPF', 'TSHEYQ73GNGGWWZ9', 'TSHEYR7EUQFPWTRY', 'TSHEYR7EZYZAG39H', 'TSHEYR7EA9SSFU59', 'TSHEXH5AG4TYGSEH', 'TSHEYR7EQWZZ6JJH', 'TSHEYQ73SSGUP3FN', 'TSHEXH59KYGCHCMU', 'TSHEXH59ZZGMGDGG', 'TSHEXH59ZCT5CGHF', 'TSHF3HJHQKFZHSXH', 'TSHEXH59VWFSPVZ7', 'ETHFYB46QHB6PMYG', 'KTAFTMYM2VYNZACZ', 'ETHFVPK3BTQXCHPS', 'KTAFTMYMA4UFJKY9', 'KTAFTMYMSEUHBE7Y', 'KTAFTMYMFAH4YAG8', 'KTAFTMYM5NVZNFRM', 'ETHFYB47G8RMQ4GS', 'ETHFW2PYA9PEWPW8', 'ETHFVPUVWNFZZS7W', 'ETHFVPUVNZVHRDSW', 'ETHFVPUVE5VSHZAM', 'ETHFW2PYUGMHSYGS', 'ETHFYB47ZTGRQ8CQ', 'ETHFW2PYKRVQJFAA', 'ETHFYB47HW5MHKJP', 'ETHFVPK3ZPWCC4YX', 'ETHFW2PYNYSH92Z6', 'ETHFYB47FDPG7MKY', 'ETHFYB47YX63WZZV', 'ETHFYB46E4NAKBBS', 'SHTFFJTPYXHNBHUY', 'TKPFUGG2J4GBNFZH', 'TSHFVWCPUWY7YAPP', 'SHTFA82ZG5GJBHMX', 'SHTFA82Z7DYRZVRD', 'SHTFA82ZK95WV8DK', 'SHTFA82Z9JAZRZXU', 'SHTF5RCSSJWXP7TR', 'SHTFA82ZRSGX7KR5', 'SHTF4FDXJCXDYFGH', 'SHTF79GAYSZ8F9S6', 'SHTFMY2XUV3DSZVW', 'SHTFYGBANZEDPSUU', 'SHTF4ZCCRZZRUJDF', 'SHTF4FDXZP2KDQKA', 'SHTF5RCSEDKQGGWG', 'SHTF4Z74EGXWHB94', 'SHTF4FDX4GHEBWJ6', 'SHTF4FDXFWNEVHGC', 'SHTF4FDXFFUB7XMN', 'SHTF4Z74X3YZD2NY', 'SHTFMY2XKBNZFZPZ', 'SHTF4ZCCBTQT4VFA', 'SHTF4Z74D66V8AVQ', 'SHTF4NAXYUN8ZT5B', 'SHTEYFZVZQ9ZC3MQ', 'SHTF4FDXVNMQHUQM', 'SHTF4ZCCGTDSQCVK', 'SHTF4ZCCMGQH8DUQ', 'SHTF4ZCCG2EGZDVZ', 'SHTF4ZCCFU7V66BS', 'SHTFA82ZZSANMWK9', 'SHTFN2EPBYAMUFHM', 'WSCFXYGWAWDRCAFP', 'JCKFUCYG2GKYHYWN', 'TSHF6RWFHSCZFJFC', 'TSHF6H6KX4VRWEGU', 'TSHF6H6KMJBMHDJX', 'TSHFPYDTG7ERZUSS', 'TSHFUSFDAS3AGBPF', 'TSHFWFMBZDDRMZ3S', 'TSHFWFMWMPACUNEP', 'TSHF5FFXPGVDYYRH', 'TSHF4Y42YPT2GXPZ', 'TSHFUTHFFN8VMHNW', 'TSHFUTG5JZGFTXDF', 'TSHFUSFDCVNNHAJP', 'TSHFUSFDDU8HMWXM', 'TSHF2NZWZRFHSYCZ', 'TSHF2NZWBB5GGACT', 'TSHFUSFD5FBWR8NW', 'TSHFFU55ESCNYQG7', 'TSHEY5TTSV4PHDAF', 'TSHF34PEGC9AENZH', 'TSHF6TYMGYT2G7HJ', 'TSHFUSFDSBBBG6ZF', 'TSHFFU559ZXYHYGS', 'TSHF2KRV5R3YXC75', 'TSHFFU55GBSDETGJ', 'TSHF2GDG5SXDJG7Q', 'TSHF2GDGBBDHJSHA', 'TSHF3A67WUAH8NGC', 'TSHF2KRVKSYWA8G7', ...
# women DF = 0.479 : ['TKPFCZ9EA7H5FYZH', 'TKPFCZ9ESZZ7YWEF', 'TKPFCZ9EVXKBSUD7', 'TKPFCZ9EFK9DNWDA', 'TKPFDABN3GXYPFHE', 'TKPFCZ9ESGZYT8NH', 'TKPFCZ9DYU33FFXS', 'TKPFZ4YTJZWBFYFZ', 'TKPFZ4YTGNZJDZDU', 'TKPFCZ9EHCNAPKPU', 'TKPFD3K6K5TNYZGF', 'TKPFCZ9EGGYENTZS', 'TKPFD3K62JB9PEMR', 'TKPFCZ9EZDPZR5AH', 'TKPFWBGPGVKVZARU', 'TKPFCZ9EVM2GZ4GF', 'TKPFWAG7YFWPMG5Y', 'SOCFVCCYUDEN2AVH', 'CTPFVZTEMJWEJJJV', 'CTPFVZHSA7G4PFC5', 'CTPFVZT3UFN99ZTH', 'CTPFVSU7CXFCXEHD', 'CTPFVZGRKPGSFPUU', 'CTPFVZT2GYAVYEE6', 'CTPFVZHFTSBTMH9M', 'CTPFVZEYHCRQ27Y2', 'CTPFVZFYR8KGYYBJ', 'CTPFVQNGFCRGYK2H', 'CTPFVPN4CUY6QZXD', 'CTPFVZT9ZYJB4WJZ', 'CTPFVZTZNFBGXUMD', 'CTPFVQSGZGPHUEFX', 'CTPFVZTBN4GRZKXH', 'CTPFVPKKWBZUCH7Y', 'CTPFVZGY4PQHQNFH', 'CTPFVPH2JGZRW6FV', 'CTPFVPJZKBVGK2FV', 'CTPFVSXYFFS9XHDG', 'CTPFVPFPUWYQC9M5', 'CTPFVPFPHGWGF6DS', 'CTPFVHUJMZSAHPFG', 'CTPFVPGPW8DU3XJF', 'CTPFVPGH5AGD8PZX', 'CTPFVPJ7HY68S45F', 'CTPFWYNJF8KMYKWG', 'CTPFVSU95M2RQUCM', 'CTPFVSXF9FNZGKXP', 'CTPFVZTBFX56AB3T', 'CTPFVZT38N9RHZTA', 'SWTFYGS7GFGWVX4J', 'SWTFYHPVHZSVMHYR', 'SCFFYKYC46ZEZAUH', 'SWTFYGQAJ53QGAW8', 'SWTFYGPQREHCG5ZK', 'SWTFYHNM8SAQGHGM', 'TSHFWSZJZNHNPX2Y', 'TSHFWTPXBG5SZDV7', 'SHTFVVEHGJJTM4QN', 'TSHFYC82QNATNDPD', 'TSHFWTPXPEDHXUQQ', 'SHTFVVEHWHRGQMKY', 'TSHFYF6KNCXDJRFG', 'TSHFZ67FC4P49NFW', 'TSHFWSZJFCQGDD9R', 'TSHFZ67FCHGZ6HB4', 'TSHFWTMGVUBKW4M8', 'TSHFYEESCZZGQVDJ', 'TSHFWTMGFADKY7S8', 'TSHFWTRVHHXNDYVZ', 'SHTFVVCNTBZUFGXR', 'TSHFYF6BFWFHZCG4', 'TSHFYFASJGCMTFZJ', 'TSHFYFATXGZDX5WB', 'TSHFYFASFTHCYMHG', 'TSHFYFKS6JUSUTUS', 'TSHFYFASMT4X5T4V', 'TSHFYFASCWHRDGGH', 'TSHFYFASNXPF75MU', 'TSHFYFASJWVNGVZG', 'TSHFYFASXCZ5MQYX', 'TSHFYFKPGYZJBY48', 'SHTFVVEHMCY2GYFC', 'SHTFVVEHGDUN99HD', 'TSHFWYY3UQVQTDMN', 'SHTFVVEHZUETFQAM', 'SHTFVVCNH3ECDGVF', 'TSHFYFATJ5AH3GFG', 'TSHFWSZJH9S7WR2K', 'TSHFEFDH45GYQBXS', 'TSHFZF6KATPWGGZP', 'SRTFZFYXGWCDRYNT', 'TKPFZYYR52RZQPHD', 'TSHFZF6K8RPHSGYP', 'TSHFZF6KVN4ZVV9D', 'TSHFZF6KBHPZZHRH', 'TSHFZF6KMXA75HRY', 'TSHFZF6KZTHBEFC6', 'TSHFZF6KDGVRSZKN', 'SRTFZFYX7HCSRDD7', 'TSHFZF6KYWWNYBNJ', 'TSHFZF6KAAJ3QBBZ', 'TSHFZF6KZ4HCF9DU', 'SRTFZYYSMRZZHSNR', 'SRTFZFYXANT8QBUS', 'TSHFZF6KYJYERPXZ', 'SRTFZFYXMNKHST7D', 'SRTFZYYVN7EQ8QGH', 'TSHFZF6KGMMYWQSN', 'TSHFZF6KF2GKH5ZM', 'TSHFZF6KAZXKZ76F', 'TSHFZF6KFHSFFGCC', 'TSHFZF6K9ZAWXRNW', 'TSHFZF6KFDXJS4V5', 'TSHFZF6K9WDTTBHP', 'TSHFZF6KRWWZFF2F', 'TSHFZF6KFFUBMGTU', 'TSHFZF6KXEHPYESC', 'TSHFZF6K9SMXHMG5', 'TSHFZF6KFQWJPA6Q', 'TKPFZYYNUE65UKZQ', 'SOCFMYWYTGDZY6NZ', 'SOCFMYWYZDNV4ZHR', 'SOCFJZBZSUG2CWSY', 'SOCFAEKEPDWZYGEG', 'SOCFAEKFTC9QVR7Y', 'SOCFAJY9ZKQQEU6Y', 'SOCFFMT7U5VXXCUV', 'SOCFMYZVHVEGQMVY', 'SOCFMYZV6J8PGGGX', 'SOCFMFJFANEFCHF8', 'SOCFMFJFGM9CAMZR', 'VESFHJHPZUSZP2H2', 'VESFHJHQF7YJ3DHH', 'TSHFGYGH8Z6CQT4B', 'VESFGYJDGBAHTK8A', 'TSHFKYKQ2UHZZAXF', 'VESFZAMXSDYEC5JB', 'BXRFH3SGHKWHQCQA', 'BXRFGYQUTHXJKHHP', 'BXRFGGX685HKER8Y', 'TSHFGYGHHBF6AVWE', 'BXRFENA7KXWEUGQF', 'VESFZR4CKHWRG4AF', 'VESFGYJDQVNEA6DE', 'VESFGYJDTX7WJBT7', 'TSHFHJKRU3HPDFEJ', 'VESFZGBYSAZWVKGA', 'VESFZGBWT5KQYFVW', 'VESFGYJDBKHSE5H6', 'VESFZAGYDM5FZYTD', 'VESFGYJCNNHV7KNG', 'VESFGYJDAGF4QZ3V', 'VESFZAM6DPFT2VHZ', 'VESFYUQJSMSA6ADG', 'VESFZANYWFQFYXZ2', 'TSHFGG5SHU3GER2F', 'VESFYUQJYKGZZNFZ', 'VESFYUTS3NCU6XQZ', 'TSHFHJKR4CAKQVC5', 'TSHFHJKRCHG8R7YS', 'VESFGJZGXKKQZGFJ', 'VESFZAHF3QEQAR4E', 'VESFHJHQ2VPZV4F7', 'BXRFGYVBFFRQSY4Z', 'VESFYUT6JN8FBUM5', 'VESFZAKZ2ADEZEHM', 'VESFGYJCX9TZN6ZC', 'VESFGYJCDFVVHR4U', 'VESFHJHPGC9CW6XA', 'TSHFZ5UVAKHJ5GGY', 'VESFZAZWJBRBHMAB', 'TSHFHJKRJBUK2TFG', 'SRTFHZ5V5CFUZQM5', 'VESFHYSXFN3GANGR', 'VESFZ95QDTSNJZYG', 'VESFHJHP4AYNWSAZ', 'VESFZ95Q4FHSKHGF', 'BXRFENA8YZPM8PMR', 'VESFGYJDJNXBANFG', 'VESFGYJCU2PM9HXR', 'VESFHJHPBCYZGZHE', 'VESFKYJPMPAC8M9S', 'VESFHJHPCZH2ACVK', 'VESFGYJCZH7GMD4E', 'VESFGYJDWUH364V2', 'VESFKYJQBYHWE5ZA', 'DHYFHYT3QQU3UTNC', 'TSHFGYGHDVUZBNZA', 'VESFHYSUYB7DBAZZ', 'VESFKYJREF5THSAN', 'TSHFHJKSVR5D3HHG', 'VESFGYJDFBUZG6FQ', 'TSHFGYGHMVYZFWUG', 'TSHFZ5UVTYC3T7NB', 'TSHFHJKRAVBBXFWF', 'TSHFHJKS88WDXB7Z', 'VESFHRDCY32K427Y', 'TSHFZAHZWFJACVVB', 'VESFZAGW4AG8WJUF',  ...

# %% [markdown]
# ## 2. Propose test queries

# %%
q1 = "casual half sleeve polo shirt for men"
q2 = "light blue jeans slim fit"
q3 = "trousers chino casual men"
q4 = "black sports shoes"
q5 = "fancy t-shirt"

q = []
q.append(q1)
q.append(q2)
q.append(q3)
q.append(q4)
q.append(q5)

for i in range(5):
    query_terms = build_terms(q[i])

    result_docs = set(inverted_index.get(query_terms[0], []))

    for term in query_terms[1:]:
        result_docs &= set(inverted_index.get(term, []))

    print(result_docs)
# Out:
# {'TSHFFYTQNA9CXMTZ', 'TSHFG2HT6EMKGP7W', 'TSHFK68CSHUDZWAD', 'TSHFFXX4YMHWGGPF', 'TSHFK68PHMV7JVRU', 'TSHFPD3VM8GGGEEX', 'TSHFHVPB7F33EBNN', 'TSHEGHGENWAEJ3JV', 'TSHFK68GQPGQEVZK', 'TSHFHVPBAUCHFQ3K', 'TSHFG2HTPGKEK3WX', 'TSHFG2HTNYF2VG9Q', 'TSHFK68RZ9PZDXFK', 'TSHFG2HTQDXM3SQX', 'TSHEG64SDHDEZAGH', 'TSHFZP6HBDFGFWFC', 'TSHFPKNC3JEGVQCZ', 'TSHFG2HTXEHZNGGZ', 'TSHFG2HTPXQAWZTS', 'TSHEG5Y3ZNYCADMV', 'TSHEG5FPJMEZQXBD', 'TSHFHVPBFGSGVXFM', 'TSHFHVPBVZ9HY9GG', 'TSHFHVPBFZSXYHEP', 'TSHFKZYFJ8DXYPJG', 'TSHFHVPBF4BJYW7N', 'TSHFHVPBYQP9SNBP', 'TSHFFXTHJPHFU8HA', 'TSHFFXTNZRTNP9JG', 'TSHFPKNCFYGMWDDH', 'TSHFK68SC4GBWKHN', 'TSHFK68PGB5P77Z3', 'TSHFG2HTNZJZEPUH', 'TSHFG2HTGWSVXBZB', 'TSHFHVPBSDYRNG9N', 'TSHFPKNCFHB6QTFP', 'TSHEGHG2YWG7TZJQ', 'TSHFG2HTBE9JC7D9', 'TSHFPKNCQAQFNVKB', 'TSHFK68HVCGVFQZE', 'TSHFG2HT2XZVHGPH', 'TSHFG2HT8YNZHWA5', 'TSHFG2HTZBX7RMGZ'}
# {'JEAFPMKZGHS2ZTKG', 'JEAFTZFX7HR5HZVW', 'JEAFUZXSHCZNHQE4', 'JEAFRARNKDFYXUYW', 'JEAFWH29FHYPZFSE', 'JEAFWH29AAGEZANB', 'JEAFH5H7ZNHRZQBJ', 'JEAFEC2GEMGBWHA5', 'JEAFRAQYJAGJSJUY', 'JEAEHGRJSGGYEYYX', 'JEAFRARNXEQRZAYY', 'JEAFPMKZC5EYHCHZ', 'JEAFRAQVRVMEUZUZ', 'JEAFWH29ZSDRZCZ8', 'JEAFSKYHHDQ2SDZQ', 'BZRFZR4FJTHHFNMZ', 'JEAFZQ8YZB7EBFHA', 'JEAFWH29GZ8MYGGY', 'JEAFRARZ8V5JXDVU', 'JEAFUZXT2J3VV2RR', 'JEAFW4DUEGRPEYDR', 'TSHE6WQC3WHWXNPZ'}
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[61], line 17
#      14 for i in range(5):
#      15     query_terms = build_terms(q[i])
# ---> 17     result_docs = set(inverted_index.get(query_terms[0], []))
#      19     for term in query_terms[1:]:
#      20         result_docs &= set(inverted_index.get(term, []))
#
# IndexError: list index out of range

# %% [markdown]
# ## 3. Rank your results

# %%
def create_index_tfidf_products(products):
    index = defaultdict(list)
    tf = defaultdict(list)
    df = defaultdict(int)
    idf = defaultdict(float)
    title_index = defaultdict(str)

    num_documents = len(products)

    for i in range(num_documents):
        pid = products.iloc[i]["pid"]
        words = products.iloc[i]["title_description"]
        title_index[pid] = products.iloc[i].get("title", "")

        current_product_index = {}

        for position, term in enumerate(words):
            try:
                current_product_index[term][1].append(position)
            except:
                current_product_index[term] = [pid, array('I', [position])]

        norm = math.sqrt(sum(len(posting[1]) ** 2 for posting in current_product_index.values()))

        for term, posting in current_product_index.items():
            tf[term].append(np.round(len(posting[1]) / norm, 4))
            df[term] += 1

        for term, posting in current_product_index.items():
            index[term].append(posting)

    for term in df:
        idf[term] = np.round(np.log(float(num_documents / df[term])), 4)

    return index, tf, df, idf, title_index

def rank_documents(terms, prods, index, idf, tf, title_index):
    product_vectors = defaultdict(lambda: [0] * len(terms))
    query_vector = [0] * len(terms)

    query_terms_count = collections.Counter(terms)
    query_norm = la.norm(list(query_terms_count.values()))

    for term_index, term in enumerate(terms):
        if term not in index:
            continue

        query_vector[term_index] = query_terms_count[term] / query_norm * idf[term]

        for posting_index, (pid, positions) in enumerate(index[term]):
            if pid in prods:
                product_vectors[pid][term_index] = tf[term][posting_index] * idf[term]

    product_scores = [[np.dot(vec, query_vector), pid] for pid, vec in product_vectors.items()]
    product_scores.sort(reverse=True)
    ranked_prods = [pid for _, pid in product_scores]

    return ranked_prods, product_scores

def search_tf_idf(query, index, idf, tf, title_index):
    query = build_terms(query)
    prods = None

    for term in query:
        try:
            term_prods = set(posting[0] for posting in index[term])
            if prods is None:
                prods = term_prods
            else:
                prods &= term_prods
        except:
            return [], []

    if not prods:
        return [], []

    prods = list(prods)
    ranked_prods, prod_scores = rank_documents(query, prods, index, idf, tf, title_index)
    return ranked_prods, prod_scores

# %%
index, tf, df, idf, title_index = create_index_tfidf_products(products)

# %%
print("Insert your query:\n")
query = input()
print(query)

ranked_prods, scores = search_tf_idf(query, index, idf, tf, title_index)
top = 10

print("\n======================\nTop {} results out of {} for the searched query:\n".format(top, len(ranked_prods)))
# for score, pid in scores[:top]:
#     print("product_id = {} - product_title: {} - score: {:.4f}".format(products[products["pid"] == pid]["url"], title_index[pid], score))

for score, pid in scores[:top]:
    url = products.loc[products["pid"] == pid, "url"].values
    url = url[0] if len(url) > 0 else "N/A"
    print("product_id = {} - product_title: {} - score: {:.4f} - url: {}".format(pid, title_index[pid], score, url))
# Out:
# Insert your query:
#
# black sports shoes
#
# ======================
# Top 10 results out of 60 for the searched query:
#
# product_id = SHOFN3EJHXHGSGUC - product_title: RS-7250 Running Shoes For Men  (Black) - score: 8.7852 - url: https://www.flipkart.com/vector-x-rs-7250-running-shoes-men/p/itm315827b1dcd91?pid=SHOFN3EJHXHGSGUC&lid=LSTSHOFN3EJHXHGSGUCGWFHSS&marketplace=FLIPKART&srno=b_5_189&otracker=nmenu_sub_Men_0_Footwear&fm=organic&iid=2c9c6405-15f7-4765-be59-536d21002294.SHOFN3EJHXHGSGUC.SEARCH&ssid=z6yjmdcc8w0000001612688550527
# product_id = SHOFN3EJZKBG6QUF - product_title: JAGUAR Football Shoes For Women  (Red, Black) - score: 8.3345 - url: https://www.flipkart.com/vector-x-jaguar-football-shoes-men/p/itmb9b13375a136c?pid=SHOFN3EJZKBG6QUF&lid=LSTSHOFN3EJZKBG6QUFNSOSIE&marketplace=FLIPKART&srno=b_2_62&otracker=nmenu_sub_Men_0_Footwear&fm=organic&iid=ed342989-9f17-43c2-b620-87aa4485e449.SHOFN3EJZKBG6QUF.SEARCH&ssid=3u6pawgow00000001612688548473
# product_id = SHOFUH52V5AVNHMN - product_title: Loafers For Men  (Black) - score: 5.3780 - url: https://www.flipkart.com/bonexy-loafers-men/p/itm1e009dae6f7b7?pid=SHOFUH52V5AVNHMN&lid=LSTSHOFUH52V5AVNHMNOFKK8J&marketplace=FLIPKART&srno=b_3_88&otracker=nmenu_sub_Men_0_Footwear&fm=organic&iid=808ae14d-03e8-4469-804b-6525b9271ee1.SHOFUH52V5AVNHMN.SEARCH&ssid=zh5c7ofn9s0000001612687775142
# product_id = SHOFX2G6FHVNAHZN - product_title: Loafers For Women  (Black) - score: 5.2340 - url: https://www.flipkart.com/bonexy-loafers-men/p/itm23d387bf5b8dc?pid=SHOFX2G6FHVNAHZN&lid=LSTSHOFX2G6FHVNAHZNOFD874&marketplace=FLIPKART&srno=b_1_5&otracker=nmenu_sub_Men_0_Footwear&fm=organic&iid=60bce454-5fce-46d0-997f-6bf4aafc9c3d.SHOFX2G6FHVNAHZN.SEARCH&ssid=9a2pecj24w0000001612687773586
# product_id = SHOFVXG5XR59AFTH - product_title: Lace Up For Men  (Black) - score: 5.2340 - url: https://www.flipkart.com/bonexy-lace-up-men/p/itm6225a24faff46?pid=SHOFVXG5XR59AFTH&lid=LSTSHOFVXG5XR59AFTHYZWSY7&marketplace=FLIPKART&srno=b_3_93&otracker=nmenu_sub_Men_0_Footwear&fm=organic&iid=808ae14d-03e8-4469-804b-6525b9271ee1.SHOFVXG5XR59AFTH.SEARCH&ssid=zh5c7ofn9s0000001612687775142
# product_id = SHOFVJX2TP8FRR7P - product_title: Lace Up For Men  (Black) - score: 5.2340 - url: https://www.flipkart.com/bonexy-lace-up-men/p/itmfe9bb2538a268?pid=SHOFVJX2TP8FRR7P&lid=LSTSHOFVJX2TP8FRR7PDUS5IB&marketplace=FLIPKART&srno=b_3_115&otracker=nmenu_sub_Men_0_Footwear&fm=organic&iid=808ae14d-03e8-4469-804b-6525b9271ee1.SHOFVJX2TP8FRR7P.SEARCH&ssid=zh5c7ofn9s0000001612687775142
# product_id = SHOFVHY8MAYUPTZF - product_title: Loafers For Men  (Black) - score: 5.2340 - url: https://www.flipkart.com/bonexy-loafers-men/p/itmf976e23f2b92e?pid=SHOFVHY8MAYUPTZF&lid=LSTSHOFVHY8MAYUPTZFB4ADRT&marketplace=FLIPKART&srno=b_3_97&otracker=nmenu_sub_Men_0_Footwear&fm=organic&iid=808ae14d-03e8-4469-804b-6525b9271ee1.SHOFVHY8MAYUPTZF.SEARCH&ssid=zh5c7ofn9s0000001612687775142
# product_id = SHOE7TZFE2TCNPH5 - product_title: Sports Shoes For Women  (Black, Yellow) - score: 4.6496 - url: https://www.flipkart.com/vector-x-sports-shoes-men/p/itmf3x9nawzud6sc?pid=SHOE7TZFE2TCNPH5&lid=LSTSHOE7TZFE2TCNPH5ON7MYR&marketplace=FLIPKART&srno=b_4_150&otracker=nmenu_sub_Men_0_Footwear&fm=organic&iid=39cd0f32-17f1-4b96-b66f-031eb5a9fa63.SHOE7TZFE2TCNPH5.SEARCH&ssid=oxr1fcm7ps0000001612688549818
# product_id = SHOFJGUAGAVDZ8CJ - product_title: Slip On For Men  (Black) - score: 4.6052 - url: https://www.flipkart.com/bonexy-slip-men/p/itmce5b9a96fef27?pid=SHOFJGUAGAVDZ8CJ&lid=LSTSHOFJGUAGAVDZ8CJ27DXTT&marketplace=FLIPKART&srno=b_2_62&otracker=nmenu_sub_Men_0_Footwear&fm=organic&iid=88d4419d-60b6-4a7b-83d5-083647273b93.SHOFJGUAGAVDZ8CJ.SEARCH&ssid=kok955yw6o0000001612687774372
# product_id = SHOEHEJBDHMQHASJ - product_title: Blaze Football Shoes For Men  (Black) - score: 4.5498 - url: https://www.flipkart.com/vector-x-blaze-football-shoes-men/p/itmf3xtxe7uvwcbd?pid=SHOEHEJBDHMQHASJ&lid=LSTSHOEHEJBDHMQHASJ1TRL7K&marketplace=FLIPKART&srno=b_2_71&otracker=nmenu_sub_Men_0_Footwear&fm=organic&iid=ed342989-9f17-43c2-b620-87aa4485e449.SHOEHEJBDHMQHASJ.SEARCH&ssid=3u6pawgow00000001612688548473

# %% [markdown]
# ## 4. Evaluation

# %%
def precision_at_k(doc_score, y_score, k=10):
    """
    Parameters
    ----------
    doc_score: dict mapping doc_id to ground truth relevance (0 or 1)
    y_score: list of tuples (doc_id, predicted_score)
    k : number of docs to consider

    Returns
    -------
    precision @k : float
    """
    sorted_docs = sorted(y_score, key=lambda x: x[1], reverse=True)

    top_k_docs = [doc_id for doc_id, _ in sorted_docs[:k]]

    relevant = sum(doc_score.get(doc_id, 0) == 1 for doc_id in top_k_docs)

    return float(relevant) / k

# %%
def recall_at_k(doc_score, y_score, k=10):
    """
    Parameters
    ----------
    doc_score: dict mapping doc_id to ground truth relevance (0 or 1)
    y_score: list of tuples (doc_id, predicted_score)
    k : number of docs to consider

    Returns
    -------
    recall @k : float
    """
    sorted_docs = sorted(y_score, key=lambda x: x[1], reverse=True)

    top_k_docs = [doc_id for doc_id, _ in sorted_docs[:k]]

    relevant_retrieved = sum(doc_score.get(doc_id, 0) == 1 for doc_id in top_k_docs)

    total_relevant = sum(1 for relevance in doc_score.values() if relevance == 1)

    if total_relevant == 0:
        return 0.0

    return float(relevant_retrieved) / total_relevant

# %%
def avg_precision_at_k(doc_score, y_score, k=10):
    sorted_docs = sorted(y_score, key=lambda x: x[1], reverse=True)
    top_k = sorted_docs[:k]

    relevant = 0
    precision_sum = 0.0

    for i, (pid, _) in enumerate(top_k, start=1):
        if doc_score.get(pid, 0) == 1:
            relevant += 1
            precision_sum += relevant / i

    if relevant == 0:
        return 0.0

    return precision_sum / relevant

# %%
def f1_score_at_k(doc_score, y_score, k=10):
    sorted_docs = sorted(y_score, key=lambda x: x[1], reverse=True)
    top_k = sorted_docs[:k]

    relevant_retrieved = sum(doc_score.get(pid, 0) == 1 for pid, _ in top_k)
    total_relevant = sum(1 for rel in doc_score.values() if rel == 1)

    precision = relevant_retrieved / k if k > 0 else 0
    recall = relevant_retrieved / total_relevant if total_relevant > 0 else 0

    if precision + recall == 0:
        return 0.0

    return 2 * (precision * recall) / (precision + recall)

# %%
def map_at_k(all_doc_scores, all_y_scores, k=10):
    ap_list = []
    for doc_score, y_score in zip(all_doc_scores, all_y_scores):
        ap_list.append(avg_precision_at_k(doc_score, y_score, k))
    return np.mean(ap_list), ap_list

# %%
def rr_at_k(doc_score, y_score, k=10):
    sorted_docs = sorted(y_score, key=lambda x: x[1], reverse=True)
    top_k = sorted_docs[:k]

    for rank, (pid, _) in enumerate(top_k, start=1):
        if doc_score.get(pid, 0) == 1:
            return 1.0 / rank
    return 0.0

# %%
def dcg_at_k(doc_score, y_score, k=10):
    sorted_docs = sorted(y_score, key=lambda x: x[1], reverse=True)
    top_k = sorted_docs[:k]

    gains = [(2 ** doc_score.get(pid, 0) - 1) for pid, _ in top_k]
    discounts = np.log2(np.arange(len(gains)) + 2)

    return np.sum(np.array(gains) / discounts)

def ndcg_at_k(doc_score, y_score, k=10):
    ideal_y_score = [(pid, doc_score.get(pid, 0)) for pid in doc_score]
    ideal_dcg = dcg_at_k(doc_score, ideal_y_score, k)
    if ideal_dcg == 0:
        return 0.0
    return np.round(dcg_at_k(doc_score, y_score, k) / ideal_dcg, 4)

# %%
df = pd.read_csv("../../data/validation_labels.csv")

query_texts = {
    1: "women full sleeve sweatshirt cotton",
    2: "men slim jeans blue"
}

processed_queries = {qid: build_terms(text) for qid, text in query_texts.items()}

relevance_maps = {}
for query_id, group in df.groupby("query_id"):
    processed_query = tuple(processed_queries[query_id])
    relevance_maps[processed_query] = {
        row["pid"]: int(row["labels"]) for _, row in group.iterrows()
    }

for query_id, terms in processed_queries.items():
    query_key = tuple(terms)
    ranked_prods, prod_scores = rank_documents(terms, list(relevance_maps[query_key].keys()), index, idf, tf, title_index)
    y_score = [(pid, score) for score, pid in prod_scores]
    doc_score = relevance_maps[query_key]
    

    p_at_10 = round(precision_at_k(doc_score, y_score, k=10), 3)
    r_at_10 = round(recall_at_k(doc_score, y_score, k=10), 3)
    ap_at_10 = round(avg_precision_at_k(doc_score, y_score, k=10), 3)
    f1_at_10 = round(f1_score_at_k(doc_score, y_score, k=10), 3)
    rr = round(rr_at_k(doc_score, y_score, k=10), 3)
    ndcg = round(ndcg_at_k(doc_score, y_score, k=10), 3)

    print(f"{p_at_10}")
    print(f"{r_at_10}")
    print(f"{ap_at_10}")
    print(f"{f1_at_10}")
    print(f"{rr}")
    print(f"{ndcg}")
    print()

    # print("Top 10 products:")
    # for score, pid in prod_scores[:10]:
    #     title = title_index.get(pid, "N/A")
    #     print(f"{pid} - {title}")
    # print()

    # Collect all scores for MAP@10
all_doc_scores = []
all_y_scores = []

for query_id, terms in processed_queries.items():
    query_key = tuple(terms)
    ranked_prods, prod_scores = rank_documents(terms, list(relevance_maps[query_key].keys()), index, idf, tf, title_index)
    y_score = [(pid, score) for score, pid in prod_scores]
    doc_score = relevance_maps[query_key]

    all_doc_scores.append(doc_score)
    all_y_scores.append(y_score)

mean_ap, ap_list = map_at_k(all_doc_scores, all_y_scores, k=10)

print("MAP@10:")
print(f"{round(mean_ap, 3)}")
for ap in ap_list:
    print(f"{round(ap, 3)}", end=" ")
# Out:
# 1.0
# 0.769
# 1.0
# 0.87
# 1.0
# 1.0
#
# 0.6
# 0.6
# 0.68
# 0.6
# 1.0
# 0.615
#
# MAP@10:
# 0.84
# 1.0 0.68
